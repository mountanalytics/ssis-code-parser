# %%
import pandas as pd
import os
import json
import xmltodict
import json
import xml.etree.ElementTree as ET

# %%
# parse nodes - generic parser

def parse_dtsx(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    # Define namespaces
    namespaces = {
        'DTS': 'www.microsoft.com/SqlServer/Dts'
    }
    
    # Function to parse Executable elements
    def parse_executables(executables):
        for executable in executables:
            exec_type = executable.attrib.get(f'{{{namespaces["DTS"]}}}ExecutableType')
            name = executable.attrib.get(f'{{{namespaces["DTS"]}}}Name')
            refid = executable.attrib.get(f'{{{namespaces["DTS"]}}}refId')
            description = executable.attrib.get(f'{{{namespaces["DTS"]}}}Description')
            object_data = executable.attrib.get(f'{{{namespaces["DTS"]}}}ObjectData')


            print(f'Executable: {name}, Type: {exec_type}, refId: {refid}, description: {description}, object data: {object_data}')
            
            # Check for nested executables
            nested_executables = executable.findall('DTS:Executables/DTS:Executable', namespaces)
            if nested_executables:
                parse_executables(nested_executables)


    
    # Parse control flow
    print("Control Flow:")
    executables = root.findall('.//DTS:Executable', namespaces)
    parse_executables(executables)
    
    # Parse data flow components
    print("\nData Flow Components:")
    data_flows = root.findall('.//DTS:Executable[@DTS:ExecutableType="SSIS.Pipeline.2"]/DTS:ObjectData/pipeline/components/component', namespaces)
    for component in data_flows:
        comp_name = component.attrib.get('name')
        comp_class_id = component.attrib.get('componentClassID')
        print(f'Component: {comp_name}, ClassID: {comp_class_id}')

# Example usage
file_path = 'data/DailyETLMain.dtsx'
parse_dtsx(file_path)
# Out:
# Control Flow:
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Calculate ETL Cutoff Time backup, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Ensure Date Dimension includes current year, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load City Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load City Dimension\Extract Updated City Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Get Last City ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Migrate Staged City Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load City Dimension\Set TableName to City, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Truncate City_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load City Dimension\Extract Updated City Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Get Last City ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Migrate Staged City Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load City Dimension\Set TableName to City, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load City Dimension\Truncate City_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Customer Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Customer Dimension\Extract Updated Customer Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Get Last Customer ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Migrate Staged Customer Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Customer Dimension\Set TableName to Customer, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Truncate Customer_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Customer Dimension\Extract Updated Customer Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Get Last Customer ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Migrate Staged Customer Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Customer Dimension\Set TableName to Customer, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Customer Dimension\Truncate Customer_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Employee Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Employee Dimension\Extract Updated Employee Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Get Last Employee ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Migrate Staged Employee Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Employee Dimension\Set TableName to Employee, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Truncate Employee_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Employee Dimension\Extract Updated Employee Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Get Last Employee ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Migrate Staged Employee Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Employee Dimension\Set TableName to Employee, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Employee Dimension\Truncate Employee_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Movement Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Movement Fact\Extract Updated Movement Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Migrate Staged Movement Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Movement Fact\Set TableName to Movement, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Truncate Movement_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Movement Fact\Extract Updated Movement Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Migrate Staged Movement Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Movement Fact\Set TableName to Movement, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Movement Fact\Truncate Movement_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Order Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Order Fact\Extract Updated Order Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Migrate Staged Order Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Order Fact\Set TableName to Order, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Truncate Order_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Order Fact\Extract Updated Order Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Migrate Staged Order Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Order Fact\Set TableName to Order, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Order Fact\Truncate Order_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Payment Method Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Payment Method Dimension\Extract Updated Payment Method Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Get Last Payment Method ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Migrate Staged Payment Method Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Payment Method Dimension\Set TableName to Payment Method, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Truncate PaymentMethod_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Payment Method Dimension\Extract Updated Payment Method Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Get Last Payment Method ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Migrate Staged Payment Method Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Payment Method Dimension\Set TableName to Payment Method, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Payment Method Dimension\Truncate PaymentMethod_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Purchase Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Purchase Fact\Extract Updated Purchase Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Migrate Staged Purchase Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Purchase Fact\Set TableName to Purchase, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Truncate Purchase_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Purchase Fact\Extract Updated Purchase Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Migrate Staged Purchase Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Purchase Fact\Set TableName to Purchase, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Purchase Fact\Truncate Purchase_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Sale Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Sale Fact\Extract Updated Sale Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Migrate Staged Sale Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Sale Fact\Set TableName to Sale, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Truncate Sale_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Sale Fact\Extract Updated Sale Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Migrate Staged Sale Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Sale Fact\Set TableName to Sale, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Sale Fact\Truncate Sale_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Stock Holding Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Stock Holding Fact\Extract All Stock Holding Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Migrate Staged Stock Holding Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Stock Holding Fact\Set TableName to Stock Holding, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Truncate StockHolding_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Stock Holding Fact\Extract All Stock Holding Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Migrate Staged Stock Holding Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Stock Holding Fact\Set TableName to Stock Holding, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Holding Fact\Truncate StockHolding_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Stock Item Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Stock Item Dimension\Extract Updated Stock Item Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Get Last Stock Item ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Migrate Staged Stock Item Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Stock Item Dimension\Set TableName to Stock Item, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Truncate StockItem_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Stock Item Dimension\Extract Updated Stock Item Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Get Last Stock Item ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Migrate Staged Stock Item Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Stock Item Dimension\Set TableName to Stock Item, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Stock Item Dimension\Truncate StockItem_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Supplier Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Supplier Dimension\Extract Updated Supplier Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Get Last Supplier ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Migrate Staged Supplier Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Supplier Dimension\Set TableName to Supplier, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Truncate Supplier_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Supplier Dimension\Extract Updated Supplier Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Get Last Supplier ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Migrate Staged Supplier Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Supplier Dimension\Set TableName to Supplier, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Supplier Dimension\Truncate Supplier_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Transaction Fact, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Transaction Fact\Extract Updated Transaction Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Migrate Staged Transaction Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Transaction Fact\Set TableName to Transaction, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Truncate Transaction_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Transaction Fact\Extract Updated Transaction Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Get Last Movement ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Migrate Staged Transaction Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Transaction Fact\Set TableName to Transaction, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Fact\Truncate Transaction_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: STOCK:SEQUENCE, refId: Package\Load Transaction Type Dimension, description: Sequence Container, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Transaction Type Dimension\Extract Updated Transaction Type Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Get Last Transaction Type ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Migrate Staged Transaction Type Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Transaction Type Dimension\Set TableName to Transaction Type, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Truncate TransactionType_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.Pipeline, refId: Package\Load Transaction Type Dimension\Extract Updated Transaction Type Data to Staging, description: Data Flow Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Get Last Transaction Type ETL Cutoff Time, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Get Lineage Key, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Migrate Staged Transaction Type Data, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Load Transaction Type Dimension\Set TableName to Transaction Type, description: Expression Task, object data: None
# Executable: None, Type: Microsoft.ExecuteSQLTask, refId: Package\Load Transaction Type Dimension\Truncate TransactionType_Staging, description: Execute SQL Task, object data: None
# Executable: None, Type: Microsoft.ExpressionTask, refId: Package\Trim Any Milliseconds, description: Expression Task, object data: None
#
# Data Flow Components:

# %%
# parse nodes - DailyETLMain.dtsx specific


# Define namespaces
namespaces = {
    'DTS': 'www.microsoft.com/SqlServer/Dts'
}

# Function to parse Executable elements (Control Flow)
def parse_executables(executables, depth=0):
    executables_info = []
    for executable in executables:
        exec_type = executable.attrib.get(f'{{{namespaces["DTS"]}}}ExecutableType')
        name = executable.attrib.get(f'{{{namespaces["DTS"]}}}Name')
        refid = executable.attrib.get(f'{{{namespaces["DTS"]}}}refId')
        description = executable.attrib.get(f'{{{namespaces["DTS"]}}}Description')
        object_data = executable.attrib.get(f'{{{namespaces["DTS"]}}}ObjectData')

        executables_info.append({'name': name, 'type': exec_type, 'depth': depth, 'refid': refid, 'description': description, 'object_data': object_data})
        
        # Check for nested executables
        nested_executables = executable.findall('DTS:Executables/DTS:Executable', namespaces)
        if nested_executables:
            executables_info.extend(parse_executables(nested_executables, depth + 1))
    
    return executables_info

# Function to parse Data Flow components
def parse_data_flows(data_flow_tasks):
    data_flow_info = []
    for task in data_flow_tasks:
        task_name = task.attrib.get(f'{{{namespaces["DTS"]}}}Name')
        components = task.findall('.//component', namespaces)
        for component in components:
            comp_name = component.attrib.get('name')
            comp_class_id = component.attrib.get('componentClassID')
            data_flow_info.append({'task_name': task_name, 'component_name': comp_name, 'classID': comp_class_id})
    return data_flow_info

# Load and parse the uploaded .dtsx file
def parse_dtsx(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Parse control flow
    control_flow = parse_executables(root.findall('.//DTS:Executable', namespaces))
    
    # Parse data flow tasks
    data_flow_tasks = root.findall('.//DTS:Executable[@DTS:ExecutableType="Microsoft.Pipeline"]', namespaces)
    data_flow_info = parse_data_flows(data_flow_tasks)
    
    return control_flow, data_flow_info

# Example usage
file_path = 'data/DailyETLMain.dtsx'
control_flow, data_flow_info = parse_dtsx(file_path)

(control_flow, data_flow_info)
# Out:
# ([{'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Calculate ETL Cutoff Time backup',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Ensure Date Dimension includes current year',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Extract Updated City Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Migrate Staged City Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Set TableName to City',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load City Dimension\\Truncate City_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Extract Updated City Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Migrate Staged City Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Set TableName to City',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load City Dimension\\Truncate City_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Get Last Customer ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Migrate Staged Customer Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Set TableName to Customer',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Customer Dimension\\Truncate Customer_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Get Last Customer ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Migrate Staged Customer Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Set TableName to Customer',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Customer Dimension\\Truncate Customer_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Extract Updated Employee Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Get Last Employee ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Migrate Staged Employee Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Set TableName to Employee',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Employee Dimension\\Truncate Employee_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Extract Updated Employee Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Get Last Employee ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Migrate Staged Employee Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Set TableName to Employee',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Employee Dimension\\Truncate Employee_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Extract Updated Movement Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Migrate Staged Movement Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Set TableName to Movement',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Movement Fact\\Truncate Movement_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Extract Updated Movement Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Migrate Staged Movement Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Set TableName to Movement',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Movement Fact\\Truncate Movement_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Extract Updated Order Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Migrate Staged Order Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Set TableName to Order',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Order Fact\\Truncate Order_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Extract Updated Order Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Migrate Staged Order Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Set TableName to Order',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Order Fact\\Truncate Order_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Extract Updated Payment Method Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Get Last Payment Method ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Migrate Staged Payment Method Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Set TableName to Payment Method',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Payment Method Dimension\\Truncate PaymentMethod_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Extract Updated Payment Method Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Get Last Payment Method ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Migrate Staged Payment Method Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Set TableName to Payment Method',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Payment Method Dimension\\Truncate PaymentMethod_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Extract Updated Purchase Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Migrate Staged Purchase Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Set TableName to Purchase',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Purchase Fact\\Truncate Purchase_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Extract Updated Purchase Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Migrate Staged Purchase Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Set TableName to Purchase',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Purchase Fact\\Truncate Purchase_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Extract Updated Sale Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Migrate Staged Sale Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Set TableName to Sale',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Sale Fact\\Truncate Sale_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Extract Updated Sale Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Migrate Staged Sale Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Set TableName to Sale',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Sale Fact\\Truncate Sale_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Extract All Stock Holding Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Migrate Staged Stock Holding Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Set TableName to Stock Holding',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Holding Fact\\Truncate StockHolding_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Extract All Stock Holding Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Migrate Staged Stock Holding Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Set TableName to Stock Holding',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Holding Fact\\Truncate StockHolding_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Extract Updated Stock Item Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Get Last Stock Item ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Migrate Staged Stock Item Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Set TableName to Stock Item',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Stock Item Dimension\\Truncate StockItem_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Extract Updated Stock Item Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Get Last Stock Item ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Migrate Staged Stock Item Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Set TableName to Stock Item',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Stock Item Dimension\\Truncate StockItem_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Extract Updated Supplier Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Get Last Supplier ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Migrate Staged Supplier Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Set TableName to Supplier',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Supplier Dimension\\Truncate Supplier_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Extract Updated Supplier Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Get Last Supplier ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Migrate Staged Supplier Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Set TableName to Supplier',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Supplier Dimension\\Truncate Supplier_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Extract Updated Transaction Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Migrate Staged Transaction Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Set TableName to Transaction',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Fact\\Truncate Transaction_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Extract Updated Transaction Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Get Last Movement ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Migrate Staged Transaction Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Set TableName to Transaction',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Fact\\Truncate Transaction_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'STOCK:SEQUENCE',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension',
#    'description': 'Sequence Container',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Get Last Transaction Type ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Migrate Staged Transaction Type Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Set TableName to Transaction Type',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 1,
#    'refid': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.Pipeline',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging',
#    'description': 'Data Flow Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Get Last Transaction Type ETL Cutoff Time',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Get Lineage Key',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Migrate Staged Transaction Type Data',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Set TableName to Transaction Type',
#    'description': 'Expression Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExecuteSQLTask',
#    'depth': 0,
#    'refid': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging',
#    'description': 'Execute SQL Task',
#    'object_data': None},
#   {'name': None,
#    'type': 'Microsoft.ExpressionTask',
#    'depth': 0,
#    'refid': 'Package\\Trim Any Milliseconds',
#    'description': 'Expression Task',
#    'object_data': None}],
#  [{'task_name': None,
#    'component_name': 'Integration_City_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetCityUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Customer_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetCustomerUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Employee_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetEmployeeUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_GetMovementUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Movement_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetOrderUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Order_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetPaymentMethodUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_PaymentMethod_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetPurchaseUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Purchase_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetSaleUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Sale_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetStockHoldingUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_StockHolding_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetStockItemUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_StockItem_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetSupplierUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Supplier_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetTransactionUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_Transaction_Staging',
#    'classID': 'Microsoft.OLEDBDestination'},
#   {'task_name': None,
#    'component_name': 'Integration_GetTransactionTypeUpdates',
#    'classID': 'Microsoft.OLEDBSource'},
#   {'task_name': None,
#    'component_name': 'Integration_TransactionType_Staging',
#    'classID': 'Microsoft.OLEDBDestination'}])

# %%
# different approach: convert to json (json is easier to read)

def convert_xml_to_json(xml_file, json_file):
    with open(xml_file, 'r') as file:
        xml_content = file.read()
    
    # Convert XML to a dictionary
    data_dict = xmltodict.parse(xml_content)
    
    # Convert dictionary to JSON
    json_data = json.dumps(data_dict, indent=4)
    
    # Write JSON data to a file
    with open(json_file, 'w') as file:
        file.write(json_data)
    
    print(f"Converted {xml_file} to {json_file}")

# Specify the input XML file and output JSON file
xml_file = 'data/Lesson 6.dtsx'
json_file = 'data/output.json'

convert_xml_to_json(xml_file, json_file)
# Out:
# Converted data/Lesson 6.dtsx to output.json

# %%
class Load():
    def __init__(self, path):
        self.path = path


    def remove_at_signs(self, obj):
        if isinstance(obj, dict):
            return {key.replace('@', ''): self.remove_at_signs(value) for key, value in obj.items()}
        elif isinstance(obj, list):
            return [self.remove_at_signs(item) for item in obj]
        else:
            return obj
        

    def remove_first_layer(self, json_dict):
        # Extract values from the first layer
        values = list(json_dict.values())
        return values

    def run(self):

        # Path to the XML file
        with open(self.path, 'rb') as f:
            self.xml = f.read()

   
        # open the xml file
        o = xmltodict.parse(self.xml)  # every time you reload the file in colab the key changes (file (1).xml becomes file (2).xml ...)

        json = self.remove_first_layer(self.remove_at_signs(o))[0]

        return json
    




files = [file for file in os.listdir('data/')]
#files = [file for file in os.listdir('data/Creating a Simple ETL Package/Completed Packages/')]

nodes_list = []
filter_list = []

for file in files[:3]:
    

    if file.endswith('.dtsx'):
        print(file)
        json = Load(f"data/{file}").run()
        #json = Load(f'data/Creating a Simple ETL Package/Completed Packages/{file}').run()
    #print(json)
# Out:
# DailyETLMain.dtsx

# %%
json
# Out:
# {'xmlns:DTS': 'www.microsoft.com/SqlServer/Dts',
#  'DTS:refId': 'Package',
#  'DTS:CreationDate': '4/10/2016 11:13:19 AM',
#  'DTS:CreationName': 'Microsoft.Package',
#  'DTS:CreatorComputerName': 'GREG7440WIN10',
#  'DTS:CreatorName': 'GREG7440WIN10\\Greg',
#  'DTS:DTSID': '{1688CC04-248C-44DC-9B43-C8D2DE1DE3FD}',
#  'DTS:ExecutableType': 'Microsoft.Package',
#  'DTS:LastModifiedProductVersion': '13.0.4001.0',
#  'DTS:LocaleID': '3081',
#  'DTS:ObjectName': 'DailyETLMain',
#  'DTS:PackageType': '5',
#  'DTS:ProtectionLevel': '0',
#  'DTS:VersionBuild': '62',
#  'DTS:VersionGUID': '{00A1E197-21DE-4954-AAA0-E348461E172E}',
#  'DTS:Property': {'DTS:Name': 'PackageFormatVersion', '#text': '8'},
#  'DTS:Variables': {'DTS:Variable': [{'DTS:CreationName': '',
#     'DTS:DTSID': '{60BD9010-4784-49A6-8FF2-340D7AB3B70D}',
#     'DTS:IncludeInDebugDump': '6789',
#     'DTS:Namespace': 'User',
#     'DTS:ObjectName': 'LastETLCutoffTime',
#     'DTS:VariableValue': {'DTS:DataType': '7',
#      '#text': '4/11/2016 10:39:10 AM'}},
#    {'DTS:CreationName': '',
#     'DTS:DTSID': '{9D06A177-1D56-4B5E-8C82-4DC4143EF9D6}',
#     'DTS:IncludeInDebugDump': '6789',
#     'DTS:Namespace': 'User',
#     'DTS:ObjectName': 'LineageKey',
#     'DTS:VariableValue': {'DTS:DataType': '3', '#text': '0'}},
#    {'DTS:CreationName': '',
#     'DTS:DTSID': '{A8F7D5F4-D7CF-4AF1-870C-845532B79B6F}',
#     'DTS:IncludeInDebugDump': '2345',
#     'DTS:Namespace': 'User',
#     'DTS:ObjectName': 'TableName',
#     'DTS:VariableValue': {'DTS:DataType': '8', 'xml:space': 'preserve'}},
#    {'DTS:CreationName': '',
#     'DTS:DTSID': '{B96D08A3-EC4E-45C1-8E78-526920753C6B}',
#     'DTS:IncludeInDebugDump': '6789',
#     'DTS:Namespace': 'User',
#     'DTS:ObjectName': 'TargetETLCutoffTime',
#     'DTS:VariableValue': {'DTS:DataType': '7',
#      '#text': '4/13/2016 11:25:23 AM'}}]},
#  'DTS:Executables': {'DTS:Executable': [{'DTS:refId': 'Package\\Calculate ETL Cutoff Time backup',
#     'DTS:CreationName': 'Microsoft.ExpressionTask',
#     'DTS:Description': 'Expression Task',
#     'DTS:DTSID': '{1AB43A83-F682-4D1A-B54D-5B6D71A27FBD}',
#     'DTS:ExecutableType': 'Microsoft.ExpressionTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Calculate ETL Cutoff Time backup',
#     'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TargetETLCutoffTime] = DATEADD("Minute", -5, GETUTCDATE()  )'}}},
#    {'DTS:refId': 'Package\\Ensure Date Dimension includes current year',
#     'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#     'DTS:Description': 'Execute SQL Task',
#     'DTS:DTSID': '{92E7FED7-B5B8-4831-8623-7E5C7931DDF8}',
#     'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Ensure Date Dimension includes current year',
#     'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#       'SQLTask:SqlStatementSource': 'DECLARE @YearNumber int =  YEAR(SYSUTCDATETIME());\n\nEXEC Integration.PopulateDateDimensionForYear @YearNumber;',
#       'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}},
#    {'DTS:refId': 'Package\\Load City Dimension',
#     'DTS:CreationName': 'STOCK:SEQUENCE',
#     'DTS:Description': 'Sequence Container',
#     'DTS:DTSID': '{035B143D-3ADA-42F4-8824-972E2DE9514C}',
#     'DTS:ExecutableType': 'STOCK:SEQUENCE',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Load City Dimension',
#     'DTS:Variables': None,
#     'DTS:Executables': {'DTS:Executable': [{'DTS:refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging',
#        'DTS:CreationName': 'Microsoft.Pipeline',
#        'DTS:Description': 'Data Flow Task',
#        'DTS:DTSID': '{F2DAF031-DD28-49EA-95CA-E6E97A3194CE}',
#        'DTS:ExecutableType': 'Microsoft.Pipeline',
#        'DTS:LocaleID': '-1',
#        'DTS:ObjectName': 'Extract Updated City Data to Staging',
#        'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#        'DTS:Variables': None,
#        'DTS:ObjectData': {'pipeline': {'version': '1',
#          'components': {'component': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging',
#             'componentClassID': 'Microsoft.OLEDBDestination',
#             'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4',
#             'description': 'OLE DB Destination',
#             'name': 'Integration_City_Staging',
#             'usesDispositions': 'true',
#             'version': '4',
#             'properties': {'property': [{'dataType': 'System.Int32',
#                'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.',
#                'name': 'CommandTimeout',
#                '#text': '0'},
#               {'dataType': 'System.String',
#                'description': 'Specifies the name of the database object used to open a rowset.',
#                'name': 'OpenRowset',
#                '#text': '[Integration].[City_Staging]'},
#               {'dataType': 'System.String',
#                'description': 'Specifies the variable that contains the name of the database object used to open a rowset.',
#                'name': 'OpenRowsetVariable'},
#               {'dataType': 'System.String',
#                'description': 'The SQL command to be executed.',
#                'name': 'SqlCommand',
#                'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'},
#               {'dataType': 'System.Int32',
#                'description': 'Specifies the column code page to use when code page information is unavailable from the data source.',
#                'name': 'DefaultCodePage',
#                '#text': '1252'},
#               {'dataType': 'System.Boolean',
#                'description': 'Forces the use of the DefaultCodePage property value when describing character data.',
#                'name': 'AlwaysUseDefaultCodePage',
#                '#text': 'false'},
#               {'dataType': 'System.Int32',
#                'description': 'Specifies the mode used to access the database.',
#                'name': 'AccessMode',
#                'typeConverter': 'AccessMode',
#                '#text': '3'},
#               {'dataType': 'System.Boolean',
#                'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.',
#                'name': 'FastLoadKeepIdentity',
#                '#text': 'false'},
#               {'dataType': 'System.Boolean',
#                'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.',
#                'name': 'FastLoadKeepNulls',
#                '#text': 'false'},
#               {'dataType': 'System.String',
#                'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.',
#                'name': 'FastLoadOptions',
#                '#text': 'CHECK_CONSTRAINTS'},
#               {'dataType': 'System.Int32',
#                'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.',
#                'name': 'FastLoadMaxInsertCommitSize',
#                '#text': '2147483647'}]},
#             'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Connections[OleDbConnection]',
#               'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external',
#               'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]',
#               'description': 'The OLE DB runtime connection used to access the database.',
#               'name': 'OleDbConnection'}},
#             'inputs': {'input': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#               'errorOrTruncationOperation': 'Insert',
#               'errorRowDisposition': 'FailComponent',
#               'hasSideEffects': 'true',
#               'name': 'OLE DB Destination Input',
#               'inputColumns': {'inputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[WWI City ID]',
#                  'cachedDataType': 'i4',
#                  'cachedName': 'WWI City ID',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[WWI City ID]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[City]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '50',
#                  'cachedName': 'City',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[State Province]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '50',
#                  'cachedName': 'State Province',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[State Province]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Country]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '50',
#                  'cachedName': 'Country',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Country]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Continent]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '30',
#                  'cachedName': 'Continent',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Continent]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Sales Territory]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '50',
#                  'cachedName': 'Sales Territory',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Sales Territory]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Region]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '30',
#                  'cachedName': 'Region',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Region]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Subregion]',
#                  'cachedDataType': 'wstr',
#                  'cachedLength': '30',
#                  'cachedName': 'Subregion',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Subregion]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Location]',
#                  'cachedDataType': 'image',
#                  'cachedName': 'Location',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Location]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Latest Recorded Population]',
#                  'cachedDataType': 'i8',
#                  'cachedName': 'Latest Recorded Population',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Latest Recorded Population]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Valid From]',
#                  'cachedDataType': 'dbTimeStamp2',
#                  'cachedName': 'Valid From',
#                  'cachedScale': '7',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid From]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Valid To]',
#                  'cachedDataType': 'dbTimeStamp2',
#                  'cachedName': 'Valid To',
#                  'cachedScale': '7',
#                  'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid To]',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]'}]},
#               'externalMetadataColumns': {'isUsed': 'True',
#                'externalMetadataColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[WWI City ID]',
#                  'dataType': 'i4',
#                  'name': 'WWI City ID'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City]',
#                  'dataType': 'wstr',
#                  'length': '50',
#                  'name': 'City'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[State Province]',
#                  'dataType': 'wstr',
#                  'length': '50',
#                  'name': 'State Province'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Country]',
#                  'dataType': 'wstr',
#                  'length': '60',
#                  'name': 'Country'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Continent]',
#                  'dataType': 'wstr',
#                  'length': '30',
#                  'name': 'Continent'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Sales Territory]',
#                  'dataType': 'wstr',
#                  'length': '50',
#                  'name': 'Sales Territory'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Region]',
#                  'dataType': 'wstr',
#                  'length': '30',
#                  'name': 'Region'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Subregion]',
#                  'dataType': 'wstr',
#                  'length': '30',
#                  'name': 'Subregion'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Location]',
#                  'dataType': 'image',
#                  'name': 'Location'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Latest Recorded Population]',
#                  'dataType': 'i8',
#                  'name': 'Latest Recorded Population'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid From]',
#                  'dataType': 'dbTimeStamp2',
#                  'name': 'Valid From',
#                  'scale': '7'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid To]',
#                  'dataType': 'dbTimeStamp2',
#                  'name': 'Valid To',
#                  'scale': '7'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City Staging Key]',
#                  'dataType': 'i4',
#                  'name': 'City Staging Key'}]}}},
#             'outputs': {'output': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output]',
#               'exclusionGroup': '1',
#               'isErrorOut': 'true',
#               'name': 'OLE DB Destination Error Output',
#               'synchronousInputId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#               'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorCode]',
#                  'dataType': 'i4',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorCode]',
#                  'name': 'ErrorCode',
#                  'specialFlags': '1'},
#                 {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorColumn]',
#                  'dataType': 'i4',
#                  'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorColumn]',
#                  'name': 'ErrorColumn',
#                  'specialFlags': '2'}]},
#               'externalMetadataColumns': None}}},
#            {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates',
#             'componentClassID': 'Microsoft.OLEDBSource',
#             'contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7',
#             'description': 'OLE DB Source',
#             'name': 'Integration_GetCityUpdates',
#             'usesDispositions': 'true',
#             'version': '7',
#             'properties': {'property': [{'dataType': 'System.Int32',
#                'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.',
#                'name': 'CommandTimeout',
#                '#text': '0'},
#               {'dataType': 'System.String',
#                'description': 'Specifies the name of the database object used to open a rowset.',
#                'name': 'OpenRowset'},
#               {'dataType': 'System.String',
#                'description': 'Specifies the variable that contains the name of the database object used to open a rowset.',
#                'name': 'OpenRowsetVariable'},
#               {'dataType': 'System.String',
#                'description': 'The SQL command to be executed.',
#                'name': 'SqlCommand',
#                'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor',
#                '#text': 'EXEC Integration.GetCityUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI City ID] int,\n        City nvarchar(50),\n        [State Province] nvarchar(50),\n        Country nvarchar(50),\n        Continent nvarchar(30),\n        [Sales Territory] nvarchar(50),\n        Region nvarchar(30),\n        Subregion nvarchar(30),\n        [Location] geography,\n        [Latest Recorded Population] bigint,\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'},
#               {'dataType': 'System.String',
#                'description': 'The variable that contains the SQL command to be executed.',
#                'name': 'SqlCommandVariable'},
#               {'dataType': 'System.Int32',
#                'description': 'Specifies the column code page to use when code page information is unavailable from the data source.',
#                'name': 'DefaultCodePage',
#                '#text': '1252'},
#               {'dataType': 'System.Boolean',
#                'description': 'Forces the use of the DefaultCodePage property value when describing character data.',
#                'name': 'AlwaysUseDefaultCodePage',
#                '#text': 'false'},
#               {'dataType': 'System.Int32',
#                'description': 'Specifies the mode used to access the database.',
#                'name': 'AccessMode',
#                'typeConverter': 'AccessMode',
#                '#text': '2'},
#               {'dataType': 'System.String',
#                'description': 'The mappings between the parameters in the SQL command and variables.',
#                'name': 'ParameterMapping',
#                '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]},
#             'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Connections[OleDbConnection]',
#               'connectionManagerID': '{E8464E14-D126-4B86-AFFB-295B0D3506F4}:external',
#               'connectionManagerRefId': 'Project.ConnectionManagers[WWI_Source_DB]',
#               'description': 'The OLE DB runtime connection used to access the database.',
#               'name': 'OleDbConnection'}},
#             'outputs': {'output': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output]',
#                'name': 'OLE DB Source Output',
#                'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]',
#                   'dataType': 'i4',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[WWI City ID]',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]',
#                   'name': 'WWI City ID',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[City]',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]',
#                   'name': 'City',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[State Province]',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]',
#                   'name': 'State Province',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Country]',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]',
#                   'name': 'Country',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Continent]',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]',
#                   'name': 'Continent',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Sales Territory]',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]',
#                   'name': 'Sales Territory',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Region]',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]',
#                   'name': 'Region',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]',
#                   'dataType': 'wstr',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Subregion]',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]',
#                   'name': 'Subregion',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]',
#                   'dataType': 'image',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Location]',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]',
#                   'name': 'Location',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]',
#                   'dataType': 'i8',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Latest Recorded Population]',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]',
#                   'name': 'Latest Recorded Population',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]',
#                   'dataType': 'dbTimeStamp2',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]',
#                   'name': 'Valid From',
#                   'scale': '7',
#                   'truncationRowDisposition': 'FailComponent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]',
#                   'dataType': 'dbTimeStamp2',
#                   'errorOrTruncationOperation': 'Conversion',
#                   'errorRowDisposition': 'FailComponent',
#                   'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid To]',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]',
#                   'name': 'Valid To',
#                   'scale': '7',
#                   'truncationRowDisposition': 'FailComponent'}]},
#                'externalMetadataColumns': {'isUsed': 'True',
#                 'externalMetadataColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[WWI City ID]',
#                   'dataType': 'i4',
#                   'name': 'WWI City ID'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[City]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'name': 'City'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[State Province]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'name': 'State Province'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Country]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'name': 'Country'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Continent]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'name': 'Continent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Sales Territory]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'name': 'Sales Territory'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Region]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'name': 'Region'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Subregion]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'name': 'Subregion'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Location]',
#                   'dataType': 'image',
#                   'name': 'Location'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Latest Recorded Population]',
#                   'dataType': 'i8',
#                   'name': 'Latest Recorded Population'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]',
#                   'dataType': 'dbTimeStamp2',
#                   'name': 'Valid From',
#                   'scale': '7'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid To]',
#                   'dataType': 'dbTimeStamp2',
#                   'name': 'Valid To',
#                   'scale': '7'}]}},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output]',
#                'isErrorOut': 'true',
#                'name': 'OLE DB Source Error Output',
#                'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[WWI City ID]',
#                   'dataType': 'i4',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[WWI City ID]',
#                   'name': 'WWI City ID'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[City]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[City]',
#                   'name': 'City'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[State Province]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[State Province]',
#                   'name': 'State Province'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Country]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Country]',
#                   'name': 'Country'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Continent]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Continent]',
#                   'name': 'Continent'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Sales Territory]',
#                   'dataType': 'wstr',
#                   'length': '50',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Sales Territory]',
#                   'name': 'Sales Territory'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Region]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Region]',
#                   'name': 'Region'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Subregion]',
#                   'dataType': 'wstr',
#                   'length': '30',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Subregion]',
#                   'name': 'Subregion'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Location]',
#                   'dataType': 'image',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Location]',
#                   'name': 'Location'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Latest Recorded Population]',
#                   'dataType': 'i8',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Latest Recorded Population]',
#                   'name': 'Latest Recorded Population'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid From]',
#                   'dataType': 'dbTimeStamp2',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid From]',
#                   'name': 'Valid From',
#                   'scale': '7'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid To]',
#                   'dataType': 'dbTimeStamp2',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid To]',
#                   'name': 'Valid To',
#                   'scale': '7'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorCode]',
#                   'dataType': 'i4',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorCode]',
#                   'name': 'ErrorCode',
#                   'specialFlags': '1'},
#                  {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorColumn]',
#                   'dataType': 'i4',
#                   'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorColumn]',
#                   'name': 'ErrorColumn',
#                   'specialFlags': '2'}]},
#                'externalMetadataColumns': None}]}}]},
#          'paths': {'path': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging.Paths[OLE DB Source Output]',
#            'endId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#            'name': 'OLE DB Source Output',
#            'startId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output]'}}}}},
#       {'DTS:refId': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time',
#        'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#        'DTS:Description': 'Execute SQL Task',
#        'DTS:DTSID': '{94e023aa-52cc-4623-90a1-d9e945d692a1}',
#        'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
# ...
#        'DTS:ObjectName': 'Get Lineage Key',
#        'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#        'DTS:ThreadHint': '0',
#        'DTS:Variables': None,
#        'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#          'SQLTask:SqlStatementSource': 'EXEC Integration.GetLineageKey ?, ?;',
#          'SQLTask:ResultType': 'ResultSetType_SingleRow',
#          'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask',
#          'SQLTask:ResultBinding': {'SQLTask:ResultName': 'LineageKey',
#           'SQLTask:DtsVariableName': 'User::LineageKey'},
#          'SQLTask:ParameterBinding': [{'SQLTask:ParameterName': '0',
#            'SQLTask:DtsVariableName': 'User::TableName',
#            'SQLTask:ParameterDirection': 'Input',
#            'SQLTask:DataType': '130',
#            'SQLTask:ParameterSize': '-1'},
#           {'SQLTask:ParameterName': '1',
#            'SQLTask:DtsVariableName': 'User::TargetETLCutoffTime',
#            'SQLTask:ParameterDirection': 'Input',
#            'SQLTask:DataType': '7',
#            'SQLTask:ParameterSize': '-1'}]}}},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Migrate Staged Transaction Type Data',
#        'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#        'DTS:Description': 'Execute SQL Task',
#        'DTS:DTSID': '{949e4f8a-e51f-489c-a195-0610db8fe70f}',
#        'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#        'DTS:LocaleID': '-1',
#        'DTS:ObjectName': 'Migrate Staged Transaction Type Data',
#        'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#        'DTS:ThreadHint': '0',
#        'DTS:Variables': None,
#        'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#          'SQLTask:SqlStatementSource': 'EXEC Integration.MigrateStagedTransactionTypeData;',
#          'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Set TableName to Transaction Type',
#        'DTS:CreationName': 'Microsoft.ExpressionTask',
#        'DTS:Description': 'Expression Task',
#        'DTS:DTSID': '{2793f1b1-97be-4459-8765-1f4e8df2d798}',
#        'DTS:ExecutableType': 'Microsoft.ExpressionTask',
#        'DTS:LocaleID': '-1',
#        'DTS:ObjectName': 'Set TableName to Transaction Type',
#        'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#        'DTS:ThreadHint': '0',
#        'DTS:Variables': None,
#        'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TableName] = "Transaction Type"'}}},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging',
#        'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#        'DTS:Description': 'Execute SQL Task',
#        'DTS:DTSID': '{c70231df-1c58-42c5-a57a-04214a4556c0}',
#        'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#        'DTS:LocaleID': '-1',
#        'DTS:ObjectName': 'Truncate TransactionType_Staging',
#        'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#        'DTS:ThreadHint': '0',
#        'DTS:Variables': None,
#        'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#          'SQLTask:SqlStatementSource': 'DELETE FROM Integration.TransactionType_Staging;',
#          'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}]},
#     'DTS:PrecedenceConstraints': {'DTS:PrecedenceConstraint': [{'DTS:refId': 'Package\\Load Transaction Type Dimension.PrecedenceConstraints[Constraint]',
#        'DTS:CreationName': '',
#        'DTS:DTSID': '{fc206f0d-1795-4548-8fcf-591f73a89167}',
#        'DTS:From': 'Package\\Load Transaction Type Dimension\\Set TableName to Transaction Type',
#        'DTS:LogicalAnd': 'True',
#        'DTS:ObjectName': 'Constraint',
#        'DTS:To': 'Package\\Load Transaction Type Dimension\\Get Lineage Key'},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension.PrecedenceConstraints[Constraint 1]',
#        'DTS:CreationName': '',
#        'DTS:DTSID': '{ccfee080-afc1-46c1-bf7d-1f886ba1ed36}',
#        'DTS:From': 'Package\\Load Transaction Type Dimension\\Get Lineage Key',
#        'DTS:LogicalAnd': 'True',
#        'DTS:ObjectName': 'Constraint 1',
#        'DTS:To': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging'},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension.PrecedenceConstraints[Constraint 2]',
#        'DTS:CreationName': '',
#        'DTS:DTSID': '{ef2e520e-a883-402d-9a34-4d1cf983ec81}',
#        'DTS:From': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging',
#        'DTS:LogicalAnd': 'True',
#        'DTS:ObjectName': 'Constraint 2',
#        'DTS:To': 'Package\\Load Transaction Type Dimension\\Get Last Transaction Type ETL Cutoff Time'},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension.PrecedenceConstraints[Constraint 3]',
#        'DTS:CreationName': '',
#        'DTS:DTSID': '{425488de-b8be-47b4-b218-451bb4a5edf9}',
#        'DTS:From': 'Package\\Load Transaction Type Dimension\\Get Last Transaction Type ETL Cutoff Time',
#        'DTS:LogicalAnd': 'True',
#        'DTS:ObjectName': 'Constraint 3',
#        'DTS:To': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging'},
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension.PrecedenceConstraints[Constraint 4]',
#        'DTS:CreationName': '',
#        'DTS:DTSID': '{87442ac3-b72c-42d0-8a46-c7b6b1b31b24}',
#        'DTS:From': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging',
#        'DTS:LogicalAnd': 'True',
#        'DTS:ObjectName': 'Constraint 4',
#        'DTS:To': 'Package\\Load Transaction Type Dimension\\Migrate Staged Transaction Type Data'}]}},
#    {'DTS:refId': 'Package\\Trim Any Milliseconds',
#     'DTS:CreationName': 'Microsoft.ExpressionTask',
#     'DTS:Description': 'Expression Task',
#     'DTS:DTSID': '{cbe59f26-38bf-4e56-bd20-37c694c38787}',
#     'DTS:ExecutableType': 'Microsoft.ExpressionTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Trim Any Milliseconds',
#     'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TargetETLCutoffTime] = DATEADD("Millisecond", 0 - DATEPART("Millisecond", @[User::TargetETLCutoffTime]), @[User::TargetETLCutoffTime])'}}}]},
#  'DTS:PrecedenceConstraints': {'DTS:PrecedenceConstraint': [{'DTS:refId': 'Package.PrecedenceConstraints[Constraint]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{383D49BD-43D3-4E85-8E29-BACD4782DC7A}',
#     'DTS:From': 'Package\\Calculate ETL Cutoff Time backup',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint',
#     'DTS:To': 'Package\\Trim Any Milliseconds'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 1]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{BFBC83C2-EC6C-4DF0-804E-ED1C71F57DC7}',
#     'DTS:From': 'Package\\Ensure Date Dimension includes current year',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 1',
#     'DTS:To': 'Package\\Load City Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 10]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{0594DF58-0479-4D58-ABF1-EDD91347DAC2}',
#     'DTS:From': 'Package\\Load Movement Fact',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 10',
#     'DTS:To': 'Package\\Load Order Fact'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 11]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{85DD5660-6F7E-490C-98C7-E97E628B3C3E}',
#     'DTS:From': 'Package\\Load Order Fact',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 11',
#     'DTS:To': 'Package\\Load Purchase Fact'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 12]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{04ECAB24-6131-4854-B3A0-5ACDAE509C99}',
#     'DTS:From': 'Package\\Load Purchase Fact',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 12',
#     'DTS:To': 'Package\\Load Sale Fact'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 13]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{D79F5902-7F6B-4D77-9763-FE60460DEC9A}',
#     'DTS:From': 'Package\\Load Sale Fact',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 13',
#     'DTS:To': 'Package\\Load Stock Holding Fact'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 14]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{FCC72957-10CD-4E93-B573-5C399BB66C77}',
#     'DTS:From': 'Package\\Load Stock Holding Fact',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 14',
#     'DTS:To': 'Package\\Load Transaction Fact'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 2]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{410117F0-A42F-4327-9459-75C990CF8075}',
#     'DTS:From': 'Package\\Trim Any Milliseconds',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 2',
#     'DTS:To': 'Package\\Ensure Date Dimension includes current year'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 3]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{46E080EC-215D-4984-BDAE-F6042F404B57}',
#     'DTS:From': 'Package\\Load City Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 3',
#     'DTS:To': 'Package\\Load Customer Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 4]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{4EC4B3F7-F383-4995-AC2F-B01E45AA8496}',
#     'DTS:From': 'Package\\Load Customer Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 4',
#     'DTS:To': 'Package\\Load Employee Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 5]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{0E770FB0-0B29-4574-9AF6-60915F829D1A}',
#     'DTS:From': 'Package\\Load Employee Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 5',
#     'DTS:To': 'Package\\Load Payment Method Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 6]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{E91AA152-CF8B-4345-9B34-73E8CFFA55EE}',
#     'DTS:From': 'Package\\Load Payment Method Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 6',
#     'DTS:To': 'Package\\Load Stock Item Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 7]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{49D25CAA-A724-4EC3-848A-BA7AA702AA14}',
#     'DTS:From': 'Package\\Load Stock Item Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 7',
#     'DTS:To': 'Package\\Load Supplier Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 8]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{5F0983D2-BB38-4028-A452-CC9ED3E5816D}',
#     'DTS:From': 'Package\\Load Supplier Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 8',
#     'DTS:To': 'Package\\Load Transaction Type Dimension'},
#    {'DTS:refId': 'Package.PrecedenceConstraints[Constraint 9]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{B61B382F-A3E8-4D62-B00C-7ADC5D41D9C0}',
#     'DTS:From': 'Package\\Load Transaction Type Dimension',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 9',
#     'DTS:To': 'Package\\Load Movement Fact'}]},
#  'DTS:DesignTimeProperties': '<?xml version="1.0"?>\n<!--This CDATA section contains the layout information of the package. The section includes information such as (x,y) coordinates, width, and height.-->\n<!--If you manually edit this section and make a mistake, you can delete it. -->\n<!--The package will still be able to load normally but the previous layout information will be lost and the designer will automatically re-arrange the elements on the design surface.-->\n<Objects\n  Version="8">\n  <!--Each node below will contain properties that do not affect runtime behavior.-->\n  <Package\n    design-time-name="Package">\n    <LayoutInfo>\n      <GraphLayout\n        Capacity="256" xmlns="clr-namespace:Microsoft.SqlServer.IntegrationServices.Designer.Model.Serialization;assembly=Microsoft.SqlServer.IntegrationServices.Graph" xmlns:mssgle="clr-namespace:Microsoft.SqlServer.Graph.LayoutEngine;assembly=Microsoft.SqlServer.Graph" xmlns:assembly="http://schemas.microsoft.com/winfx/2006/xaml" xmlns:mssgm="clr-namespace:Microsoft.SqlServer.Graph.Model;assembly=Microsoft.SqlServer.Graph">\n        <NodeLayout\n          Size="291.2,41.6"\n          Id="Package\\Calculate ETL Cutoff Time backup"\n          TopLeft="204.500000000001,149.5" />\n        <NodeLayout\n          Size="291.2,41.6"\n          Id="Package\\Ensure Date Dimension includes current year"\n          TopLeft="204.500000000001,297.366666666667" />\n        <NodeLayout\n          Size="252,41.6"\n          Id="Package\\Load City Dimension\\Extract Updated City Data to Staging"\n          TopLeft="5.50000000000006,413.5" />\n        <NodeLayout\n          Size="217.6,41.6"\n          Id="Package\\Load City Dimension\\Get Last City ETL Cutoff Time"\n          TopLeft="22.5000000000001,311.5" />\n        <NodeLayout\n          Size="156,41.6"\n          Id="Package\\Load City Dimension\\Get Lineage Key"\n          TopLeft="53.5,107.5" />\n        <NodeLayout\n          Size="196,41.6"\n          Id="Package\\Load City Dimension\\Migrate Staged City Data"\n          TopLeft="33.5000000000001,515.5" />\n        <NodeLayout\n          Size="184,41.6"\n          Id="Package\\Load City Dimension\\Set TableName to City"\n          TopLeft="39.5,5.5" />\n        <NodeLayout\n          Size="183.2,41.6"\n          Id="Package\\Load City Dimension\\Truncate City_Staging"\n          TopLeft="40,209.5" />\n        <EdgeLayout\n          Id="Package\\Load City Dimension.PrecedenceConstraints[Constraint]"\n          TopLeft="131.5,251.5">\n          <EdgeLayout.Curve>\n            <mssgle:Curve\n              StartConnector="{assembly:Null}"\n              EndConnector="0,60"\n              Start="0,0"\n              End="0,52.5">\n              <mssgle:Curve.Segments>\n                <mssgle:SegmentCollection\n                  Capacity="5">\n                  <mssgle:LineSegment\n                    End="0,52.5" />\n                </mssgle:SegmentCollection>\n              </mssgle:Curve.Segments>\n            </mssgle:Curve>\n          </EdgeLayout.Curve>\n          <EdgeLayout.Labels>\n            <EdgeLabelCollection />\n          </EdgeLayout.Labels>\n        </EdgeLayout>\n        <EdgeLayout\n          Id="Package\\Load City Dimension.PrecedenceConstraints[Constraint 1]"\n          TopLeft="131.5,353.5">\n          <EdgeLayout.Curve>\n            <mssgle:Curve\n              StartConnector="{assembly:Null}"\n              EndConnector="0,60"\n              Start="0,0"\n              End="0,52.5">\n              <mssgle:Curve.Segments>\n                <mssgle:SegmentCollection\n                  Capacity="5">\n                  <mssgle:LineSegment\n                    End="0,52.5" />\n                </mssgle:SegmentCollection>\n              </mssgle:Curve.Segments>\n            </mssgle:Curve>\n          </EdgeLayout.Curve>\n          <EdgeLayout.Labels>\n            <EdgeLabelCollection />\n          </EdgeLayout.Labels>\n        </EdgeLayout>\n        <EdgeLayout\n  ...

# %%
# for package.dtsx

print(json['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][0]['name'])
print(json['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][1]['name'])
print(json['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][2]['name'])
# Out:
# Extract Sample Currency Data
# Lookup Currency Key
# Lookup Date Key

# %%
# control flow nodes

for node in json['DTS:Executables']['DTS:Executable']:#['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][0]['name'])
    print(node['DTS:ObjectName'])
    print(node['DTS:Description'])
    print()
# Out:
# Calculate ETL Cutoff Time backup
# Expression Task
#
# Ensure Date Dimension includes current year
# Execute SQL Task
#
# Load City Dimension
# Sequence Container
#
# Load Customer Dimension
# Sequence Container
#
# Load Employee Dimension
# Sequence Container
#
# Load Movement Fact
# Sequence Container
#
# Load Order Fact
# Sequence Container
#
# Load Payment Method Dimension
# Sequence Container
#
# Load Purchase Fact
# Sequence Container
#
# Load Sale Fact
# Sequence Container
#
# Load Stock Holding Fact
# Sequence Container
#
# Load Stock Item Dimension
# Sequence Container
#
# Load Supplier Dimension
# Sequence Container
#
# Load Transaction Fact
# Sequence Container
#
# Load Transaction Type Dimension
# Sequence Container
#
# Trim Any Milliseconds
# Expression Task

# %%
# control nodes and data flow nodes

# control node for loop
for control_node in json['DTS:Executables']['DTS:Executable']:
    print(control_node)
    print(" control node name: ",control_node['DTS:ObjectName'])
    print()

    if control_node['DTS:Description'] == 'Sequence Container':
        for executable in control_node['DTS:Executables']['DTS:Executable']:
            print("     ", executable)
            print("     executable name: ", executable['DTS:ObjectName'])
            print()

            if executable['DTS:CreationName'] == 'Microsoft.Pipeline':

                for component in executable['DTS:ObjectData']['pipeline']['components']['component']:
                    print("          ", component)
                    print("          componenet name: ", component['name'])
                    print()
            elif executable['DTS:CreationName'] =='Microsoft.ExecuteSQLTask':
                print("      ", executable['DTS:ObjectData']['SQLTask:SqlTaskData']['SQLTask:SqlStatementSource'])
                print()

            else:
                print(executable['DTS:CreationName'])
                print(executable)

                print()

      

 #           try:
 #               print('Output columns:')
 #               if type(node['outputs']['output'][0]['outputColumns']['outputColumn']) == list:
 #                   for col in node['outputs']['output'][0]['outputColumns']['outputColumn']:
 #                       print(col['name'])
 #               else:
 #                   print(node['outputs']['output'][0]['outputColumns']['outputColumn']['name'])
 #           except:
 #               pass
 #           try:
 #               print('Input columns:')
#
 #               if type(node['inputs']['input']['inputColumns']['inputColumn']) == list:
 #                   for col in node['inputs']['input']['inputColumns']['inputColumn']:
 #                       print(col['cachedName'])
 #               else:
 #                   print(node['inputs']['input']['inputColumns']['inputColumn']['name'])
 #           except:
 #               pass
 #           print()
 #       print()
 #       print("######################")
 #       print()
# Out:
# {'DTS:refId': 'Package\\Calculate ETL Cutoff Time backup', 'DTS:CreationName': 'Microsoft.ExpressionTask', 'DTS:Description': 'Expression Task', 'DTS:DTSID': '{1AB43A83-F682-4D1A-B54D-5B6D71A27FBD}', 'DTS:ExecutableType': 'Microsoft.ExpressionTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Calculate ETL Cutoff Time backup', 'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TargetETLCutoffTime] = DATEADD("Minute", -5, GETUTCDATE()  )'}}}
#  control node name:  Calculate ETL Cutoff Time backup
#
# {'DTS:refId': 'Package\\Ensure Date Dimension includes current year', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{92E7FED7-B5B8-4831-8623-7E5C7931DDF8}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Ensure Date Dimension includes current year', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'DECLARE @YearNumber int =  YEAR(SYSUTCDATETIME());\n\nEXEC Integration.PopulateDateDimensionForYear @YearNumber;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#  control node name:  Ensure Date Dimension includes current year
#
# {'DTS:refId': 'Package\\Load City Dimension', 'DTS:CreationName': 'STOCK:SEQUENCE', 'DTS:Description': 'Sequence Container', 'DTS:DTSID': '{035B143D-3ADA-42F4-8824-972E2DE9514C}', 'DTS:ExecutableType': 'STOCK:SEQUENCE', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Load City Dimension', 'DTS:Variables': None, 'DTS:Executables': {'DTS:Executable': [{'DTS:refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging', 'DTS:CreationName': 'Microsoft.Pipeline', 'DTS:Description': 'Data Flow Task', 'DTS:DTSID': '{F2DAF031-DD28-49EA-95CA-E6E97A3194CE}', 'DTS:ExecutableType': 'Microsoft.Pipeline', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Extract Updated City Data to Staging', 'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:Variables': None, 'DTS:ObjectData': {'pipeline': {'version': '1', 'components': {'component': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_City_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[City_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Int ...
#  control node name:  Load City Dimension
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging', 'DTS:CreationName': 'Microsoft.Pipeline', 'DTS:Description': 'Data Flow Task', 'DTS:DTSID': '{F2DAF031-DD28-49EA-95CA-E6E97A3194CE}', 'DTS:ExecutableType': 'Microsoft.Pipeline', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Extract Updated City Data to Staging', 'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:Variables': None, 'DTS:ObjectData': {'pipeline': {'version': '1', 'components': {'component': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_City_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[City_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Connections[OleDbConnection]', 'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'inputs': {'input': {'refId ...
#      executable name:  Extract Updated City Data to Staging
#
#            {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_City_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[City_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Connections[OleDbConnection]', 'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'inputs': {'input': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]', 'errorOrTruncationOperation': 'Insert', 'errorRowDisposition': 'FailComponent', 'hasSideEffects': 'true', 'name': 'OLE DB Destination Input', 'inputColumns': {'inputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[WWI City ID]', 'cachedDataType': 'i4', 'cachedName': 'WWI City ID', 'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Inpu ...
#           componenet name:  Integration_City_Staging
#
#            {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates', 'componentClassID': 'Microsoft.OLEDBSource', 'contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7', 'description': 'OLE DB Source', 'name': 'Integration_GetCityUpdates', 'usesDispositions': 'true', 'version': '7', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetCityUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI City ID] int,\n        City nvarchar(50),\n        [State Province] nvarchar(50),\n        Country nvarchar(50),\n        Continent nvarchar(30),\n        [Sales Territory] nvarchar(50),\n        Region nvarchar(30),\n        Subregion nvarchar(30),\n        [Location] geography,\n        [Latest Recorded Population] bigint,\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}, 'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Connections[OleDbConnection]', 'connectionManagerID': '{E8464E14-D126-4B86-AFFB-295B0D3506F4}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_Source_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'outputs': {'output': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output]', 'name': 'OLE DB Source Output', 'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]', 'dataType': 'i4', 'errorOrTruncationOperation': 'Conversion', 'errorRowDisposition': 'FailComponent', 'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[WWI City ID]', 'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]', 'name': 'WWI City ID', 'truncationRowDisposition': 'FailComponent'}, {'refId': 'Package\\Load City Dimension\\Extract Updated Cit ...
#           componenet name:  Integration_GetCityUpdates
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{94e023aa-52cc-4623-90a1-d9e945d692a1}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Last City ETL Cutoff Time', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLastETLCutoffTime ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'CutoffTime', 'SQLTask:DtsVariableName': 'User::LastETLCutoffTime'}, 'SQLTask:ParameterBinding': {'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}}}}
#      executable name:  Get Last City ETL Cutoff Time
#
#        EXEC Integration.GetLastETLCutoffTime ?;
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Get Lineage Key', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{b7afb4e9-abf2-4c7d-a400-187329ce3ab5}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Lineage Key', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLineageKey ?, ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'LineageKey', 'SQLTask:DtsVariableName': 'User::LineageKey'}, 'SQLTask:ParameterBinding': [{'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}, {'SQLTask:ParameterName': '1', 'SQLTask:DtsVariableName': 'User::TargetETLCutoffTime', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '7', 'SQLTask:ParameterSize': '-1'}]}}}
#      executable name:  Get Lineage Key
#
#        EXEC Integration.GetLineageKey ?, ?;
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Migrate Staged City Data', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{7fbbab67-1e8d-4a14-ab90-0b90be5a049f}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Migrate Staged City Data', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.MigrateStagedCityData;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Migrate Staged City Data
#
#        EXEC Integration.MigrateStagedCityData;
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Set TableName to City', 'DTS:CreationName': 'Microsoft.ExpressionTask', 'DTS:Description': 'Expression Task', 'DTS:DTSID': '{679DD25B-B027-488A-B974-DD676C39BAB0}', 'DTS:ExecutableType': 'Microsoft.ExpressionTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Set TableName to City', 'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TableName] = "City"'}}}
#      executable name:  Set TableName to City
#
# Microsoft.ExpressionTask
#
#       {'DTS:refId': 'Package\\Load City Dimension\\Truncate City_Staging', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{55B10841-D492-432F-83B9-72173EBFF68C}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Truncate City_Staging', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'DELETE FROM Integration.City_Staging;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Truncate City_Staging
#
#        DELETE FROM Integration.City_Staging;
#
# {'DTS:refId': 'Package\\Load Customer Dimension', 'DTS:CreationName': 'STOCK:SEQUENCE', 'DTS:Description': 'Sequence Container', 'DTS:DTSID': '{4C51B6E7-C1C3-490F-B64F-0185D0471346}', 'DTS:ExecutableType': 'STOCK:SEQUENCE', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Load Customer Dimension', 'DTS:Variables': None, 'DTS:Executables': {'DTS:Executable': [{'DTS:refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging', 'DTS:CreationName': 'Microsoft.Pipeline', 'DTS:Description': 'Data Flow Task', 'DTS:DTSID': '{57563110-0da5-400e-8cb7-2cf0358988a5}', 'DTS:ExecutableType': 'Microsoft.Pipeline', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Extract Updated Customer Data to Staging', 'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:Variables': None, 'DTS:ObjectData': {'pipeline': {'version': '1', 'components': {'component': [{'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_Customer_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Customer_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load Customer Dimensio ...
#  control node name:  Load Customer Dimension
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging', 'DTS:CreationName': 'Microsoft.Pipeline', 'DTS:Description': 'Data Flow Task', 'DTS:DTSID': '{57563110-0da5-400e-8cb7-2cf0358988a5}', 'DTS:ExecutableType': 'Microsoft.Pipeline', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Extract Updated Customer Data to Staging', 'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:Variables': None, 'DTS:ObjectData': {'pipeline': {'version': '1', 'components': {'component': [{'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_Customer_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Customer_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging.Connections[OleDbConnection]', 'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'Ole ...
#      executable name:  Extract Updated Customer Data to Staging
#
#            {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_Customer_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Customer_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging.Connections[OleDbConnection]', 'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'inputs': {'input': {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging.Inputs[OLE DB Destination Input]', 'errorOrTruncationOperation': 'Insert', 'errorRowDisposition': 'FailComponent', 'hasSideEffects': 'true', 'name': 'OLE DB Destination Input', 'inputColumns': {'inputColumn': [{'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_Customer_Staging.Inputs[OLE DB Destination Input].Columns[Valid From]', 'cachedDataType': 'dbTimeStamp2', 'cachedName': 'Valid From', 'cachedScale': '7', 'externalMetadataColumnId': 'Package\\Load Customer Dimension\\Extra ...
#           componenet name:  Integration_Customer_Staging
#
#            {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates', 'componentClassID': 'Microsoft.OLEDBSource', 'contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7', 'description': 'OLE DB Source', 'name': 'Integration_GetCustomerUpdates', 'usesDispositions': 'true', 'version': '7', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetCustomerUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Customer ID] int,\n        Customer nvarchar(100),\n        [Bill To Customer] nvarchar(100),\n        Category nvarchar(50),\n        [Buying Group] nvarchar(50),\n        [Primary Contact] nvarchar(50),\n        [Postal Code] nvarchar(10),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}, 'connections': {'connection': {'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates.Connections[OleDbConnection]', 'connectionManagerID': '{E8464E14-D126-4B86-AFFB-295B0D3506F4}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_Source_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'outputs': {'output': [{'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates.Outputs[OLE DB Source Output]', 'name': 'OLE DB Source Output', 'outputColumns': {'outputColumn': [{'refId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates.Outputs[OLE DB Source Output].Columns[Valid From]', 'dataType': 'dbTimeStamp2', 'errorOrTruncationOperation': 'Conversion', 'errorRowDisposition': 'FailComponent', 'externalMetadataColumnId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]', 'lineageId': 'Package\\Load Customer Dimension\\Extract Updated Customer Data to Staging\\Integration_GetCustomerUpdates.Outputs[OLE DB Source Output].Columns[Valid From]', 'name': 'Valid From', 'scale': '7', 'truncationRowDisposition': 'FailComponent'}, {'refId': 'Package\\Load Customer Dimension\\ ...
#           componenet name:  Integration_GetCustomerUpdates
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Get Last Customer ETL Cutoff Time', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{00292786-3a3f-43eb-85de-2dfe7c036110}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Last Customer ETL Cutoff Time', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLastETLCutoffTime ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'CutoffTime', 'SQLTask:DtsVariableName': 'User::LastETLCutoffTime'}, 'SQLTask:ParameterBinding': {'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}}}}
#      executable name:  Get Last Customer ETL Cutoff Time
#
#        EXEC Integration.GetLastETLCutoffTime ?;
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Get Lineage Key', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{179f0f1e-1a2a-4ebe-8bb1-eda5e47776b7}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Lineage Key', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLineageKey ?, ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'LineageKey', 'SQLTask:DtsVariableName': 'User::LineageKey'}, 'SQLTask:ParameterBinding': [{'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}, {'SQLTask:ParameterName': '1', 'SQLTask:DtsVariableName': 'User::TargetETLCutoffTime', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '7', 'SQLTask:ParameterSize': '-1'}]}}}
#      executable name:  Get Lineage Key
#
#        EXEC Integration.GetLineageKey ?, ?;
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Migrate Staged Customer Data', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{87a20694-bb6b-4f9a-8a64-a3fc48f74bf3}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Migrate Staged Customer Data', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.MigrateStagedCustomerData;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Migrate Staged Customer Data
#
#        EXEC Integration.MigrateStagedCustomerData;
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Set TableName to Customer', 'DTS:CreationName': 'Microsoft.ExpressionTask', 'DTS:Description': 'Expression Task', 'DTS:DTSID': '{c8475dce-c179-4193-94ef-01af76973648}', 'DTS:ExecutableType': 'Microsoft.ExpressionTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Set TableName to Customer', 'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TableName] = "Customer"'}}}
#      executable name:  Set TableName to Customer
#
# Microsoft.ExpressionTask
#
#       {'DTS:refId': 'Package\\Load Customer Dimension\\Truncate Customer_Staging', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{c93fdcf7-9dc1-4427-b809-7178d4d96a4e}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Truncate Customer_Staging', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'DELETE FROM Integration.Customer_Staging;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Truncate Customer_Staging
#
#        DELETE FROM Integration.Customer_Staging;
#
# ...
#      executable name:  Extract Updated Transaction Type Data to Staging
#
#            {'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates', 'componentClassID': 'Microsoft.OLEDBSource', 'contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7', 'description': 'OLE DB Source', 'name': 'Integration_GetTransactionTypeUpdates', 'usesDispositions': 'true', 'version': '7', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91', '#text': 'EXEC Integration.GetTransactionTypeUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Transaction Type ID] int,\n        [Transaction Type] nvarchar(50),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}, 'connections': {'connection': {'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates.Connections[OleDbConnection]', 'connectionManagerID': '{E8464E14-D126-4B86-AFFB-295B0D3506F4}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_Source_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'outputs': {'output': [{'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates.Outputs[OLE DB Source Output]', 'name': 'OLE DB Source Output', 'outputColumns': {'outputColumn': [{'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates.Outputs[OLE DB Source Output].Columns[Valid From]', 'dataType': 'dbTimeStamp2', 'errorOrTruncationOperation': 'Conversion', 'errorRowDisposition': 'FailComponent', 'externalMetadataColumnId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]', 'lineageId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_GetTransactionTypeUpdates.Outputs[OLE DB Source Output].Columns[Valid From]', 'name': 'Valid From', 'scale': '7' ...
#           componenet name:  Integration_GetTransactionTypeUpdates
#
#            {'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_TransactionType_Staging', 'componentClassID': 'Microsoft.OLEDBDestination', 'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4', 'description': 'OLE DB Destination', 'name': 'Integration_TransactionType_Staging', 'usesDispositions': 'true', 'version': '4', 'properties': {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[TransactionType_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}, 'connections': {'connection': {'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_TransactionType_Staging.Connections[OleDbConnection]', 'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external', 'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]', 'description': 'The OLE DB runtime connection used to access the database.', 'name': 'OleDbConnection'}}, 'inputs': {'input': {'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_TransactionType_Staging.Inputs[OLE DB Destination Input]', 'errorOrTruncationOperation': 'Insert', 'errorRowDisposition': 'FailComponent', 'hasSideEffects': 'true', 'name': 'OLE DB Destination Input', 'inputColumns': {'inputColumn': [{'refId': 'Package\\Load Transaction Type Dimension\\Extract Updated Transaction Type Data to Staging\\Integration_Transact ...
#           componenet name:  Integration_TransactionType_Staging
#
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Get Last Transaction Type ETL Cutoff Time', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{065e4c54-b778-4bba-b541-a4ff2377f118}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Last Transaction Type ETL Cutoff Time', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLastETLCutoffTime ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'CutoffTime', 'SQLTask:DtsVariableName': 'User::LastETLCutoffTime'}, 'SQLTask:ParameterBinding': {'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}}}}
#      executable name:  Get Last Transaction Type ETL Cutoff Time
#
#        EXEC Integration.GetLastETLCutoffTime ?;
#
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Get Lineage Key', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{1aa2f784-6039-4a96-81f1-13a278f7f698}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Get Lineage Key', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.GetLineageKey ?, ?;', 'SQLTask:ResultType': 'ResultSetType_SingleRow', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask', 'SQLTask:ResultBinding': {'SQLTask:ResultName': 'LineageKey', 'SQLTask:DtsVariableName': 'User::LineageKey'}, 'SQLTask:ParameterBinding': [{'SQLTask:ParameterName': '0', 'SQLTask:DtsVariableName': 'User::TableName', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '130', 'SQLTask:ParameterSize': '-1'}, {'SQLTask:ParameterName': '1', 'SQLTask:DtsVariableName': 'User::TargetETLCutoffTime', 'SQLTask:ParameterDirection': 'Input', 'SQLTask:DataType': '7', 'SQLTask:ParameterSize': '-1'}]}}}
#      executable name:  Get Lineage Key
#
#        EXEC Integration.GetLineageKey ?, ?;
#
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Migrate Staged Transaction Type Data', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{949e4f8a-e51f-489c-a195-0610db8fe70f}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Migrate Staged Transaction Type Data', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'EXEC Integration.MigrateStagedTransactionTypeData;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Migrate Staged Transaction Type Data
#
#        EXEC Integration.MigrateStagedTransactionTypeData;
#
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Set TableName to Transaction Type', 'DTS:CreationName': 'Microsoft.ExpressionTask', 'DTS:Description': 'Expression Task', 'DTS:DTSID': '{2793f1b1-97be-4459-8765-1f4e8df2d798}', 'DTS:ExecutableType': 'Microsoft.ExpressionTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Set TableName to Transaction Type', 'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TableName] = "Transaction Type"'}}}
#      executable name:  Set TableName to Transaction Type
#
# Microsoft.ExpressionTask
#
#       {'DTS:refId': 'Package\\Load Transaction Type Dimension\\Truncate TransactionType_Staging', 'DTS:CreationName': 'Microsoft.ExecuteSQLTask', 'DTS:Description': 'Execute SQL Task', 'DTS:DTSID': '{c70231df-1c58-42c5-a57a-04214a4556c0}', 'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Truncate TransactionType_Staging', 'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}', 'SQLTask:SqlStatementSource': 'DELETE FROM Integration.TransactionType_Staging;', 'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}
#      executable name:  Truncate TransactionType_Staging
#
#        DELETE FROM Integration.TransactionType_Staging;
#
# {'DTS:refId': 'Package\\Trim Any Milliseconds', 'DTS:CreationName': 'Microsoft.ExpressionTask', 'DTS:Description': 'Expression Task', 'DTS:DTSID': '{cbe59f26-38bf-4e56-bd20-37c694c38787}', 'DTS:ExecutableType': 'Microsoft.ExpressionTask', 'DTS:LocaleID': '-1', 'DTS:ObjectName': 'Trim Any Milliseconds', 'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1', 'DTS:ThreadHint': '0', 'DTS:Variables': None, 'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TargetETLCutoffTime] = DATEADD("Millisecond", 0 - DATEPART("Millisecond", @[User::TargetETLCutoffTime]), @[User::TargetETLCutoffTime])'}}}
#  control node name:  Trim Any Milliseconds

# %%
control_node
# Out:
# {'DTS:refId': 'Package\\Load City Dimension',
#  'DTS:CreationName': 'STOCK:SEQUENCE',
#  'DTS:Description': 'Sequence Container',
#  'DTS:DTSID': '{035B143D-3ADA-42F4-8824-972E2DE9514C}',
#  'DTS:ExecutableType': 'STOCK:SEQUENCE',
#  'DTS:LocaleID': '-1',
#  'DTS:ObjectName': 'Load City Dimension',
#  'DTS:Variables': None,
#  'DTS:Executables': {'DTS:Executable': [{'DTS:refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging',
#     'DTS:CreationName': 'Microsoft.Pipeline',
#     'DTS:Description': 'Data Flow Task',
#     'DTS:DTSID': '{F2DAF031-DD28-49EA-95CA-E6E97A3194CE}',
#     'DTS:ExecutableType': 'Microsoft.Pipeline',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Extract Updated City Data to Staging',
#     'DTS:TaskContact': 'Performs high-performance data extraction, transformation and loading;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'pipeline': {'version': '1',
#       'components': {'component': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging',
#          'componentClassID': 'Microsoft.OLEDBDestination',
#          'contactInfo': 'OLE DB Destination;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;4',
#          'description': 'OLE DB Destination',
#          'name': 'Integration_City_Staging',
#          'usesDispositions': 'true',
#          'version': '4',
#          'properties': {'property': [{'dataType': 'System.Int32',
#             'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.',
#             'name': 'CommandTimeout',
#             '#text': '0'},
#            {'dataType': 'System.String',
#             'description': 'Specifies the name of the database object used to open a rowset.',
#             'name': 'OpenRowset',
#             '#text': '[Integration].[City_Staging]'},
#            {'dataType': 'System.String',
#             'description': 'Specifies the variable that contains the name of the database object used to open a rowset.',
#             'name': 'OpenRowsetVariable'},
#            {'dataType': 'System.String',
#             'description': 'The SQL command to be executed.',
#             'name': 'SqlCommand',
#             'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'},
#            {'dataType': 'System.Int32',
#             'description': 'Specifies the column code page to use when code page information is unavailable from the data source.',
#             'name': 'DefaultCodePage',
#             '#text': '1252'},
#            {'dataType': 'System.Boolean',
#             'description': 'Forces the use of the DefaultCodePage property value when describing character data.',
#             'name': 'AlwaysUseDefaultCodePage',
#             '#text': 'false'},
#            {'dataType': 'System.Int32',
#             'description': 'Specifies the mode used to access the database.',
#             'name': 'AccessMode',
#             'typeConverter': 'AccessMode',
#             '#text': '3'},
#            {'dataType': 'System.Boolean',
#             'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.',
#             'name': 'FastLoadKeepIdentity',
#             '#text': 'false'},
#            {'dataType': 'System.Boolean',
#             'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.',
#             'name': 'FastLoadKeepNulls',
#             '#text': 'false'},
#            {'dataType': 'System.String',
#             'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.',
#             'name': 'FastLoadOptions',
#             '#text': 'CHECK_CONSTRAINTS'},
#            {'dataType': 'System.Int32',
#             'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.',
#             'name': 'FastLoadMaxInsertCommitSize',
#             '#text': '2147483647'}]},
#          'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Connections[OleDbConnection]',
#            'connectionManagerID': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}:external',
#            'connectionManagerRefId': 'Project.ConnectionManagers[WWI_DW_Destination_DB]',
#            'description': 'The OLE DB runtime connection used to access the database.',
#            'name': 'OleDbConnection'}},
#          'inputs': {'input': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#            'errorOrTruncationOperation': 'Insert',
#            'errorRowDisposition': 'FailComponent',
#            'hasSideEffects': 'true',
#            'name': 'OLE DB Destination Input',
#            'inputColumns': {'inputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[WWI City ID]',
#               'cachedDataType': 'i4',
#               'cachedName': 'WWI City ID',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[WWI City ID]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[City]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '50',
#               'cachedName': 'City',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[State Province]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '50',
#               'cachedName': 'State Province',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[State Province]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Country]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '50',
#               'cachedName': 'Country',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Country]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Continent]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '30',
#               'cachedName': 'Continent',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Continent]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Sales Territory]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '50',
#               'cachedName': 'Sales Territory',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Sales Territory]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Region]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '30',
#               'cachedName': 'Region',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Region]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Subregion]',
#               'cachedDataType': 'wstr',
#               'cachedLength': '30',
#               'cachedName': 'Subregion',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Subregion]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Location]',
#               'cachedDataType': 'image',
#               'cachedName': 'Location',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Location]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Latest Recorded Population]',
#               'cachedDataType': 'i8',
#               'cachedName': 'Latest Recorded Population',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Latest Recorded Population]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Valid From]',
#               'cachedDataType': 'dbTimeStamp2',
#               'cachedName': 'Valid From',
#               'cachedScale': '7',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid From]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].Columns[Valid To]',
#               'cachedDataType': 'dbTimeStamp2',
#               'cachedName': 'Valid To',
#               'cachedScale': '7',
#               'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid To]',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]'}]},
#            'externalMetadataColumns': {'isUsed': 'True',
#             'externalMetadataColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[WWI City ID]',
#               'dataType': 'i4',
#               'name': 'WWI City ID'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City]',
#               'dataType': 'wstr',
#               'length': '50',
#               'name': 'City'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[State Province]',
#               'dataType': 'wstr',
#               'length': '50',
#               'name': 'State Province'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Country]',
#               'dataType': 'wstr',
#               'length': '60',
#               'name': 'Country'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Continent]',
#               'dataType': 'wstr',
#               'length': '30',
#               'name': 'Continent'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Sales Territory]',
#               'dataType': 'wstr',
#               'length': '50',
#               'name': 'Sales Territory'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Region]',
#               'dataType': 'wstr',
#               'length': '30',
#               'name': 'Region'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Subregion]',
#               'dataType': 'wstr',
#               'length': '30',
#               'name': 'Subregion'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Location]',
#               'dataType': 'image',
#               'name': 'Location'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Latest Recorded Population]',
#               'dataType': 'i8',
#               'name': 'Latest Recorded Population'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid From]',
#               'dataType': 'dbTimeStamp2',
#               'name': 'Valid From',
#               'scale': '7'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[Valid To]',
#               'dataType': 'dbTimeStamp2',
#               'name': 'Valid To',
#               'scale': '7'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input].ExternalColumns[City Staging Key]',
#               'dataType': 'i4',
#               'name': 'City Staging Key'}]}}},
#          'outputs': {'output': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output]',
#            'exclusionGroup': '1',
#            'isErrorOut': 'true',
#            'name': 'OLE DB Destination Error Output',
#            'synchronousInputId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#            'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorCode]',
#               'dataType': 'i4',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorCode]',
#               'name': 'ErrorCode',
#               'specialFlags': '1'},
#              {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorColumn]',
#               'dataType': 'i4',
#               'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Outputs[OLE DB Destination Error Output].Columns[ErrorColumn]',
#               'name': 'ErrorColumn',
#               'specialFlags': '2'}]},
#            'externalMetadataColumns': None}}},
#         {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates',
#          'componentClassID': 'Microsoft.OLEDBSource',
#          'contactInfo': 'OLE DB Source;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;7',
#          'description': 'OLE DB Source',
#          'name': 'Integration_GetCityUpdates',
#          'usesDispositions': 'true',
#          'version': '7',
#          'properties': {'property': [{'dataType': 'System.Int32',
#             'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.',
#             'name': 'CommandTimeout',
#             '#text': '0'},
#            {'dataType': 'System.String',
#             'description': 'Specifies the name of the database object used to open a rowset.',
#             'name': 'OpenRowset'},
#            {'dataType': 'System.String',
#             'description': 'Specifies the variable that contains the name of the database object used to open a rowset.',
#             'name': 'OpenRowsetVariable'},
#            {'dataType': 'System.String',
#             'description': 'The SQL command to be executed.',
#             'name': 'SqlCommand',
#             'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor',
#             '#text': 'EXEC Integration.GetCityUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI City ID] int,\n        City nvarchar(50),\n        [State Province] nvarchar(50),\n        Country nvarchar(50),\n        Continent nvarchar(30),\n        [Sales Territory] nvarchar(50),\n        Region nvarchar(30),\n        Subregion nvarchar(30),\n        [Location] geography,\n        [Latest Recorded Population] bigint,\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'},
#            {'dataType': 'System.String',
#             'description': 'The variable that contains the SQL command to be executed.',
#             'name': 'SqlCommandVariable'},
#            {'dataType': 'System.Int32',
#             'description': 'Specifies the column code page to use when code page information is unavailable from the data source.',
#             'name': 'DefaultCodePage',
#             '#text': '1252'},
#            {'dataType': 'System.Boolean',
#             'description': 'Forces the use of the DefaultCodePage property value when describing character data.',
#             'name': 'AlwaysUseDefaultCodePage',
#             '#text': 'false'},
#            {'dataType': 'System.Int32',
#             'description': 'Specifies the mode used to access the database.',
#             'name': 'AccessMode',
#             'typeConverter': 'AccessMode',
#             '#text': '2'},
#            {'dataType': 'System.String',
#             'description': 'The mappings between the parameters in the SQL command and variables.',
#             'name': 'ParameterMapping',
#             '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]},
#          'connections': {'connection': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Connections[OleDbConnection]',
#            'connectionManagerID': '{E8464E14-D126-4B86-AFFB-295B0D3506F4}:external',
#            'connectionManagerRefId': 'Project.ConnectionManagers[WWI_Source_DB]',
#            'description': 'The OLE DB runtime connection used to access the database.',
#            'name': 'OleDbConnection'}},
#          'outputs': {'output': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output]',
#             'name': 'OLE DB Source Output',
#             'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]',
#                'dataType': 'i4',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[WWI City ID]',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[WWI City ID]',
#                'name': 'WWI City ID',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[City]',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[City]',
#                'name': 'City',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[State Province]',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[State Province]',
#                'name': 'State Province',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Country]',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Country]',
#                'name': 'Country',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Continent]',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Continent]',
#                'name': 'Continent',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Sales Territory]',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Sales Territory]',
#                'name': 'Sales Territory',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Region]',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Region]',
#                'name': 'Region',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]',
#                'dataType': 'wstr',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Subregion]',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Subregion]',
#                'name': 'Subregion',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]',
#                'dataType': 'image',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Location]',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Location]',
#                'name': 'Location',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]',
#                'dataType': 'i8',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Latest Recorded Population]',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Latest Recorded Population]',
#                'name': 'Latest Recorded Population',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]',
#                'dataType': 'dbTimeStamp2',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid From]',
#                'name': 'Valid From',
#                'scale': '7',
#                'truncationRowDisposition': 'FailComponent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]',
#                'dataType': 'dbTimeStamp2',
#                'errorOrTruncationOperation': 'Conversion',
#                'errorRowDisposition': 'FailComponent',
#                'externalMetadataColumnId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid To]',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].Columns[Valid To]',
#                'name': 'Valid To',
#                'scale': '7',
#                'truncationRowDisposition': 'FailComponent'}]},
#             'externalMetadataColumns': {'isUsed': 'True',
#              'externalMetadataColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[WWI City ID]',
#                'dataType': 'i4',
#                'name': 'WWI City ID'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[City]',
#                'dataType': 'wstr',
#                'length': '50',
#                'name': 'City'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[State Province]',
#                'dataType': 'wstr',
#                'length': '50',
#                'name': 'State Province'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Country]',
#                'dataType': 'wstr',
#                'length': '50',
#                'name': 'Country'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Continent]',
#                'dataType': 'wstr',
#                'length': '30',
#                'name': 'Continent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Sales Territory]',
#                'dataType': 'wstr',
#                'length': '50',
#                'name': 'Sales Territory'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Region]',
#                'dataType': 'wstr',
#                'length': '30',
#                'name': 'Region'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Subregion]',
#                'dataType': 'wstr',
#                'length': '30',
#                'name': 'Subregion'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Location]',
#                'dataType': 'image',
#                'name': 'Location'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Latest Recorded Population]',
#                'dataType': 'i8',
#                'name': 'Latest Recorded Population'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid From]',
#                'dataType': 'dbTimeStamp2',
#                'name': 'Valid From',
#                'scale': '7'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output].ExternalColumns[Valid To]',
#                'dataType': 'dbTimeStamp2',
#                'name': 'Valid To',
#                'scale': '7'}]}},
#            {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output]',
#             'isErrorOut': 'true',
#             'name': 'OLE DB Source Error Output',
#             'outputColumns': {'outputColumn': [{'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[WWI City ID]',
#                'dataType': 'i4',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[WWI City ID]',
#                'name': 'WWI City ID'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[City]',
#                'dataType': 'wstr',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[City]',
#                'name': 'City'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[State Province]',
#                'dataType': 'wstr',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[State Province]',
#                'name': 'State Province'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Country]',
#                'dataType': 'wstr',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Country]',
#                'name': 'Country'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Continent]',
#                'dataType': 'wstr',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Continent]',
#                'name': 'Continent'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Sales Territory]',
#                'dataType': 'wstr',
#                'length': '50',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Sales Territory]',
#                'name': 'Sales Territory'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Region]',
#                'dataType': 'wstr',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Region]',
#                'name': 'Region'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Subregion]',
#                'dataType': 'wstr',
#                'length': '30',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Subregion]',
#                'name': 'Subregion'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Location]',
#                'dataType': 'image',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Location]',
#                'name': 'Location'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Latest Recorded Population]',
#                'dataType': 'i8',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Latest Recorded Population]',
#                'name': 'Latest Recorded Population'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid From]',
#                'dataType': 'dbTimeStamp2',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid From]',
#                'name': 'Valid From',
#                'scale': '7'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid To]',
#                'dataType': 'dbTimeStamp2',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[Valid To]',
#                'name': 'Valid To',
#                'scale': '7'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorCode]',
#                'dataType': 'i4',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorCode]',
#                'name': 'ErrorCode',
#                'specialFlags': '1'},
#               {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorColumn]',
#                'dataType': 'i4',
#                'lineageId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Error Output].Columns[ErrorColumn]',
#                'name': 'ErrorColumn',
#                'specialFlags': '2'}]},
#             'externalMetadataColumns': None}]}}]},
#       'paths': {'path': {'refId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging.Paths[OLE DB Source Output]',
#         'endId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_City_Staging.Inputs[OLE DB Destination Input]',
#         'name': 'OLE DB Source Output',
#         'startId': 'Package\\Load City Dimension\\Extract Updated City Data to Staging\\Integration_GetCityUpdates.Outputs[OLE DB Source Output]'}}}}},
#    {'DTS:refId': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time',
#     'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#     'DTS:Description': 'Execute SQL Task',
#     'DTS:DTSID': '{94e023aa-52cc-4623-90a1-d9e945d692a1}',
#     'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Get Last City ETL Cutoff Time',
#     'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#       'SQLTask:SqlStatementSource': 'EXEC Integration.GetLastETLCutoffTime ?;',
#       'SQLTask:ResultType': 'ResultSetType_SingleRow',
#       'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask',
#       'SQLTask:ResultBinding': {'SQLTask:ResultName': 'CutoffTime',
#        'SQLTask:DtsVariableName': 'User::LastETLCutoffTime'},
#       'SQLTask:ParameterBinding': {'SQLTask:ParameterName': '0',
#        'SQLTask:DtsVariableName': 'User::TableName',
#        'SQLTask:ParameterDirection': 'Input',
#        'SQLTask:DataType': '130',
#        'SQLTask:ParameterSize': '-1'}}}},
#    {'DTS:refId': 'Package\\Load City Dimension\\Get Lineage Key',
#     'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#     'DTS:Description': 'Execute SQL Task',
#     'DTS:DTSID': '{b7afb4e9-abf2-4c7d-a400-187329ce3ab5}',
#     'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Get Lineage Key',
#     'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#       'SQLTask:SqlStatementSource': 'EXEC Integration.GetLineageKey ?, ?;',
#       'SQLTask:ResultType': 'ResultSetType_SingleRow',
#       'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask',
#       'SQLTask:ResultBinding': {'SQLTask:ResultName': 'LineageKey',
#        'SQLTask:DtsVariableName': 'User::LineageKey'},
#       'SQLTask:ParameterBinding': [{'SQLTask:ParameterName': '0',
#         'SQLTask:DtsVariableName': 'User::TableName',
#         'SQLTask:ParameterDirection': 'Input',
#         'SQLTask:DataType': '130',
#         'SQLTask:ParameterSize': '-1'},
#        {'SQLTask:ParameterName': '1',
#         'SQLTask:DtsVariableName': 'User::TargetETLCutoffTime',
#         'SQLTask:ParameterDirection': 'Input',
#         'SQLTask:DataType': '7',
#         'SQLTask:ParameterSize': '-1'}]}}},
#    {'DTS:refId': 'Package\\Load City Dimension\\Migrate Staged City Data',
#     'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#     'DTS:Description': 'Execute SQL Task',
#     'DTS:DTSID': '{7fbbab67-1e8d-4a14-ab90-0b90be5a049f}',
#     'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Migrate Staged City Data',
#     'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#       'SQLTask:SqlStatementSource': 'EXEC Integration.MigrateStagedCityData;',
#       'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}},
#    {'DTS:refId': 'Package\\Load City Dimension\\Set TableName to City',
#     'DTS:CreationName': 'Microsoft.ExpressionTask',
#     'DTS:Description': 'Expression Task',
#     'DTS:DTSID': '{679DD25B-B027-488A-B974-DD676C39BAB0}',
#     'DTS:ExecutableType': 'Microsoft.ExpressionTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Set TableName to City',
#     'DTS:TaskContact': 'Expression Task;Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'ExpressionTask': {'Expression': '@[User::TableName] = "City"'}}},
#    {'DTS:refId': 'Package\\Load City Dimension\\Truncate City_Staging',
#     'DTS:CreationName': 'Microsoft.ExecuteSQLTask',
#     'DTS:Description': 'Execute SQL Task',
#     'DTS:DTSID': '{55B10841-D492-432F-83B9-72173EBFF68C}',
#     'DTS:ExecutableType': 'Microsoft.ExecuteSQLTask',
#     'DTS:LocaleID': '-1',
#     'DTS:ObjectName': 'Truncate City_Staging',
#     'DTS:TaskContact': 'Execute SQL Task; Microsoft Corporation; SQL Server 2016 RC2; © 2015 Microsoft Corporation; All Rights Reserved;http://www.microsoft.com/sql/support/default.asp;1',
#     'DTS:ThreadHint': '0',
#     'DTS:Variables': None,
#     'DTS:ObjectData': {'SQLTask:SqlTaskData': {'SQLTask:Connection': '{7C3E3ECC-C5AD-4675-9618-FC08465F8BC9}',
#       'SQLTask:SqlStatementSource': 'DELETE FROM Integration.City_Staging;',
#       'xmlns:SQLTask': 'www.microsoft.com/sqlserver/dts/tasks/sqltask'}}}]},
#  'DTS:PrecedenceConstraints': {'DTS:PrecedenceConstraint': [{'DTS:refId': 'Package\\Load City Dimension.PrecedenceConstraints[Constraint]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{8F499682-E5BF-4F83-9EA5-13BDE2D0B814}',
#     'DTS:From': 'Package\\Load City Dimension\\Truncate City_Staging',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint',
#     'DTS:To': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time'},
#    {'DTS:refId': 'Package\\Load City Dimension.PrecedenceConstraints[Constraint 1]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{1F203744-8889-4B20-B1B0-951A65E6C916}',
#     'DTS:From': 'Package\\Load City Dimension\\Get Last City ETL Cutoff Time',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 1',
#     'DTS:To': 'Package\\Load City Dimension\\Extract Updated City Data to Staging'},
#    {'DTS:refId': 'Package\\Load City Dimension.PrecedenceConstraints[Constraint 2]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{194A8577-CCE0-46B1-8016-54C0146FE631}',
#     'DTS:From': 'Package\\Load City Dimension\\Set TableName to City',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 2',
#     'DTS:To': 'Package\\Load City Dimension\\Get Lineage Key'},
#    {'DTS:refId': 'Package\\Load City Dimension.PrecedenceConstraints[Constraint 3]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{8852EA26-ED11-4738-9136-AEB038EF604F}',
#     'DTS:From': 'Package\\Load City Dimension\\Extract Updated City Data to Staging',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 3',
#     'DTS:To': 'Package\\Load City Dimension\\Migrate Staged City Data'},
#    {'DTS:refId': 'Package\\Load City Dimension.PrecedenceConstraints[Constraint 4]',
#     'DTS:CreationName': '',
#     'DTS:DTSID': '{092CBA2A-3BFD-4C68-95BE-3D4FD6268376}',
#     'DTS:From': 'Package\\Load City Dimension\\Get Lineage Key',
#     'DTS:LogicalAnd': 'True',
#     'DTS:ObjectName': 'Constraint 4',
#     'DTS:To': 'Package\\Load City Dimension\\Truncate City_Staging'}]}}

# %%
# data flow nodes (with sql statements)

for node in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component']:
    print("Name node:", node['name'])
    print()
    print("Description node:", node['description'])
    print()

    try:
        print('Output columns:')
        if type(node['outputs']['output'][0]['outputColumns']['outputColumn']) == list:
            for col in node['outputs']['output'][0]['outputColumns']['outputColumn']:
                print(col['name'])
        else:
            print(node['outputs']['output'][0]['outputColumns']['outputColumn']['name'])
    except:
        pass
    try:
        print('Input columns:')

        if type(node['inputs']['input']['inputColumns']['inputColumn']) == list:
            for col in node['inputs']['input']['inputColumns']['inputColumn']:
                print(col['cachedName'])
        else:
            print(node['inputs']['input']['inputColumns']['inputColumn']['name'])
    except:
        pass
    print()
    print("######################")
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 2
#       1 #for each node print attributes
# ----> 2 for node in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component']:
#       3     print("Name node:", node['name'])
#       4     print()
#
# KeyError: 'DTS:Executables'

# %%
json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][3]
# Out:
# {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key',
#  'name': 'Lookup Currency Key',
#  'componentClassID': '{671046B0-AA63-4C9F-90E4-C06E0B710CE3}',
#  'description': "Joins additional columns to the data flow by looking up values in a table. For example, join to the 'employee id' column the employees table to get 'hire date' and 'employee name'. We recommend this transformation when the lookup table can fit into memory.",
#  'usesDispositions': 'true',
#  'version': '6',
#  'contactInfo': 'Lookup;Microsoft Corporation; Microsoft SQL Server; (C) Microsoft Corporation; All Rights Reserved; http://www.microsoft.com/sql/support;6',
#  'properties': {'property': [{'name': 'SqlCommand',
#     'dataType': 'System.String',
#     'description': 'Specifies the SQL statement that generates the lookup table.',
#     'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=11.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91',
#     'expressionType': 'Notify',
#     '#text': "select * from (select * from [dbo].[DimCurrency]) as refTable\nwhere [refTable].[CurrencyAlternateKey] = 'ARS'\nOR\n[refTable].[CurrencyAlternateKey] = 'AUD'\nOR\n[refTable].[CurrencyAlternateKey] = 'BRL'\nOR\n[refTable].[CurrencyAlternateKey] = 'CAD'\nOR\n[refTable].[CurrencyAlternateKey] = 'CNY'\nOR\n[refTable].[CurrencyAlternateKey] = 'DEM'\nOR\n[refTable].[CurrencyAlternateKey] = 'EUR'\nOR\n[refTable].[CurrencyAlternateKey] = 'FRF'\nOR\n[refTable].[CurrencyAlternateKey] = 'GBP'\nOR\n[refTable].[CurrencyAlternateKey] = 'JPY'\nOR\n[refTable].[CurrencyAlternateKey] = 'MXN'\nOR\n[refTable].[CurrencyAlternateKey] = 'SAR'\nOR\n[refTable].[CurrencyAlternateKey] = 'USD'\nOR\n[refTable].[CurrencyAlternateKey] = 'VEB'"},
#    {'name': 'SqlCommandParam',
#     'dataType': 'System.String',
#     'description': 'Specifies a SQL statement that uses parameters to generate the lookup table.',
#     'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=11.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91',
#     'expressionType': 'Notify',
#     '#text': "select * from (select * from (select * from [dbo].[DimCurrency]) as refTable\nwhere [refTable].[CurrencyAlternateKey] = 'ARS'\nOR\n[refTable].[CurrencyAlternateKey] = 'AUD'\nOR\n[refTable].[CurrencyAlternateKey] = 'BRL'\nOR\n[refTable].[CurrencyAlternateKey] = 'CAD'\nOR\n[refTable].[CurrencyAlternateKey] = 'CNY'\nOR\n[refTable].[CurrencyAlternateKey] = 'DEM'\nOR\n[refTable].[CurrencyAlternateKey] = 'EUR'\nOR\n[refTable].[CurrencyAlternateKey] = 'FRF'\nOR\n[refTable].[CurrencyAlternateKey] = 'GBP'\nOR\n[refTable].[CurrencyAlternateKey] = 'JPY'\nOR\n[refTable].[CurrencyAlternateKey] = 'MXN'\nOR\n[refTable].[CurrencyAlternateKey] = 'SAR'\nOR\n[refTable].[CurrencyAlternateKey] = 'USD'\nOR\n[refTable].[CurrencyAlternateKey] = 'VEB') [refTable]\nwhere [refTable].[CurrencyAlternateKey] = ?"},
#    {'name': 'ConnectionType',
#     'dataType': 'System.Int32',
#     'description': 'Specifies the type of connection used to access the reference dataset.',
#     'typeConverter': 'LookupConnectionType',
#     '#text': '0'},
#    {'name': 'CacheType',
#     'dataType': 'System.Int32',
#     'description': 'Specifies the cache type of the lookup table.',
#     'typeConverter': 'CacheType',
#     '#text': '0'},
#    {'name': 'NoMatchBehavior',
#     'dataType': 'System.Int32',
#     'description': 'Specifies how the Lookup transformation handles rows without matching entries in the reference data set.',
#     'typeConverter': 'LookupNoMatchBehavior',
#     '#text': '0'},
#    {'name': 'NoMatchCachePercentage',
#     'dataType': 'System.Int32',
#     'description': 'Specifies the percentage of the cache that is allocated for rows with no matching entries in the reference dataset.',
#     '#text': '0'},
#    {'name': 'MaxMemoryUsage',
#     'dataType': 'System.Int32',
#     'description': 'Maximum Memory Usage for Reference Cache on a 32 bit platform.',
#     '#text': '25'},
#    {'name': 'MaxMemoryUsage64',
#     'dataType': 'System.Int64',
#     'description': 'Maximum Memory Usage for Reference Cache on a 64 bit platform.',
#     '#text': '25'},
#    {'name': 'ReferenceMetadataXml',
#     'dataType': 'System.String',
#     'description': 'Indicates whether to reference metadata in an XML format.',
#     '#text': '<referenceMetadata><referenceColumns><referenceColumn name="CurrencyKey" dataType="DT_I4" length="0" precision="0" scale="0" codePage="0"/><referenceColumn name="CurrencyAlternateKey" dataType="DT_WSTR" length="3" precision="0" scale="0" codePage="0"/><referenceColumn name="CurrencyName" dataType="DT_WSTR" length="50" precision="0" scale="0" codePage="0"/></referenceColumns></referenceMetadata>'},
#    {'name': 'ParameterMap',
#     'dataType': 'System.String',
#     'description': 'Specifies the list of lineage identifiers that map to the parameters that the SQL statement in the SQLCommand property uses. Entries in the list are separated by semicolons.',
#     'containsID': 'true',
#     '#text': '#{Package\\Foreach File in Folder\\Extract Sample Currency Data\\Extract Sample Currency Data.Outputs[Flat File Source Output].Columns[CurrencyID]};'},
#    {'name': 'DefaultCodePage',
#     'dataType': 'System.Int32',
#     'description': 'Specifies the column code page to use when code page information is unavailable from the data source.',
#     '#text': '1252'},
#    {'name': 'TreatDuplicateKeysAsError',
#     'dataType': 'System.Boolean',
#     'description': 'Determines whether duplicate keys in the reference data should be treated as errors when full cache mode is used.',
#     '#text': 'false'}]},
#  'connections': {'connection': {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Connections[OleDbConnection]',
#    'name': 'OleDbConnection',
#    'description': 'Connection manager used to access lookup data.',
#    'connectionManagerID': 'Package.ConnectionManagers[localhost.AdventureWorksDW2012]',
#    'connectionManagerRefId': 'Package.ConnectionManagers[localhost.AdventureWorksDW2012]'}},
#  'inputs': {'input': {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Inputs[Lookup Input]',
#    'name': 'Lookup Input',
#    'inputColumns': {'inputColumn': {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Inputs[Lookup Input].Columns[CurrencyID]',
#      'lineageId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Extract Sample Currency Data.Outputs[Flat File Source Output].Columns[CurrencyID]',
#      'cachedName': 'CurrencyID',
#      'cachedDataType': 'wstr',
#      'cachedLength': '3',
#      'properties': {'property': [{'name': 'JoinToReferenceColumn',
#         'dataType': 'System.String',
#         'description': 'Specifies the column in the reference table that a column joins.',
#         '#text': 'CurrencyAlternateKey'},
#        {'name': 'CopyFromReferenceColumn',
#         'dataType': 'System.Null',
#         'description': 'Specifies the column in the reference table from which a column is copied.'}]}}},
#    'externalMetadataColumns': None}},
#  'outputs': {'output': [{'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Match Output]',
#     'name': 'Lookup Match Output',
#     'exclusionGroup': '1',
#     'synchronousInputId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Inputs[Lookup Input]',
#     'errorOrTruncationOperation': 'Lookup',
#     'errorRowDisposition': 'RedirectRow',
#     'outputColumns': {'outputColumn': {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Match Output].Columns[CurrencyKey]',
#       'name': 'CurrencyKey',
#       'lineageId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Match Output].Columns[CurrencyKey]',
#       'dataType': 'i4',
#       'errorOrTruncationOperation': 'Copy Column',
#       'truncationRowDisposition': 'FailComponent',
#       'properties': {'property': {'name': 'CopyFromReferenceColumn',
#         'dataType': 'System.String',
#         'description': 'Specifies the column in the reference table from which a column is copied.',
#         '#text': 'CurrencyKey'}}}},
#     'externalMetadataColumns': None},
#    {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup No Match Output]',
#     'name': 'Lookup No Match Output',
#     'description': 'The Lookup output that handles rows with no matching entries in the reference dataset. Use this output when the NoMatchBehavior property is set to "Send rows with no matching entries to the no match output."',
#     'exclusionGroup': '1',
#     'synchronousInputId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Inputs[Lookup Input]',
#     'externalMetadataColumns': None},
#    {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Error Output]',
#     'name': 'Lookup Error Output',
#     'exclusionGroup': '1',
#     'synchronousInputId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Inputs[Lookup Input]',
#     'isErrorOut': 'true',
#     'outputColumns': {'outputColumn': [{'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Error Output].Columns[ErrorCode]',
#        'name': 'ErrorCode',
#        'lineageId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Error Output].Columns[ErrorCode]',
#        'dataType': 'i4',
#        'specialFlags': '1'},
#       {'refId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Error Output].Columns[ErrorColumn]',
#        'name': 'ErrorColumn',
#        'lineageId': 'Package\\Foreach File in Folder\\Extract Sample Currency Data\\Lookup Currency Key.Outputs[Lookup Error Output].Columns[ErrorColumn]',
#        'dataType': 'i4',
#        'specialFlags': '2'}]},
#     'externalMetadataColumns': None}]}}

# %%
# locate name source tables and transformation
# extract sql code from each node

#for property in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][4]['properties']['property']:
#    print(property['#text'])

for node in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component']:
    print("Name node:", node['name'])
    print()
    try:

        print("Connection db:", node['connections']['connection']['connectionManagerID'])
    except:
        pass
    print()

    # db: connections connection database connectionManagerId

    for property in node['properties']['property']:
        if 'sql' in property['name'].lower():
            if '#text' in property.keys():
                print(property['#text'])
                print()
    print('#########################')
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 7
#       1 # locate name source tables and transformation
#       2 # extract sql code from each node
#       3
#       4 #for property in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][4]['properties']['property']:
#       5 #    print(property['#text'])
# ----> 7 for node in json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component']:
#       8     print("Name node:", node['name'])
#       9     print()
#
# KeyError: 'DTS:Executables'

# %%
json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][4]['connections']['connection']['connectionManagerID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 json['DTS:Executables']['DTS:Executable']['DTS:Executables']['DTS:Executable']['DTS:ObjectData']['pipeline']['components']['component'][4]['connections']['connection']['connectionManagerID']
#
# KeyError: 'DTS:Executables'
