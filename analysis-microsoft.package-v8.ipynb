# %%
import pandas as pd
import os
import json
import xmltodict
import json
import xml.etree.ElementTree as ET

# %%
# parse nodes - Microsoft.Package 8


# Define namespaces
namespaces = {
    'DTS': 'www.microsoft.com/SqlServer/Dts'
}

# Function to parse Executable elements (Control Flow)
def parse_executables(executables, depth=0):
    executables_info = []
    for executable in executables:
        exec_type = executable.attrib.get(f'{{{namespaces["DTS"]}}}ExecutableType')
        name = executable.attrib.get(f'{{{namespaces["DTS"]}}}Name')
        refid = executable.attrib.get(f'{{{namespaces["DTS"]}}}refId')
        description = executable.attrib.get(f'{{{namespaces["DTS"]}}}Description')
        object_data = executable.attrib.get(f'{{{namespaces["DTS"]}}}ObjectData')

        executables_info.append({'name': name, 'type': exec_type, 'depth': depth, 'refid': refid, 'description': description, 'object_data': object_data})
        
        # Check for nested executables
        nested_executables = executable.findall('DTS:Executables/DTS:Executable', namespaces)
        if nested_executables:
            executables_info.extend(parse_executables(nested_executables, depth + 1))
    
    return executables_info

# Function to parse Data Flow components
def parse_data_flows(data_flow_tasks):
    data_flow_info = []
    for task in data_flow_tasks:
        task_name = task.attrib.get(f'{{{namespaces["DTS"]}}}Name')
        components = task.findall('.//component', namespaces)
        for component in components:
            comp_name = component.attrib.get('name')
            comp_class_id = component.attrib.get('componentClassID')
            refid = component.attrib.get('refId')
            name = component.attrib.get('name')
            data_flow_info.append({'task_name': task_name, 'component_name': comp_name, 'classID': comp_class_id, 'name':name, 'refid': refid})
    return data_flow_info

# Load and parse the uploaded .dtsx file
def parse_dtsx(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Parse control flow
    control_flow = parse_executables(root.findall('.//DTS:Executable', namespaces))
    
    # Parse data flow tasks
    data_flow_tasks = root.findall('.//DTS:Executable[@DTS:ExecutableType="Microsoft.Pipeline"]', namespaces)
    data_flow_info = parse_data_flows(data_flow_tasks)
    
    return control_flow, data_flow_info

# %%
# parse nodes - DailyETLMain.dtsx specific

# Define namespaces
namespaces = {
    'DTS': 'www.microsoft.com/SqlServer/Dts'
}

# Function to parse Executable elements (Control Flow)
def parse_executables(executables, depth=0):
    executables_info = []
    for executable in executables:
        print(executable)

       # executables_info.append({'name': name, 'type': exec_type, 'depth': depth, 'refid': refid, 'description': description, 'object_data': object_data})
        
        # Check for nested executables
        nested_executables = executable.findall('DTS:Executables/DTS:Executable')#, namespaces)
        if nested_executables:
            for i in nested_executables:
                print("    " + i)
    
    return executables_info


# Load and parse the uploaded .dtsx file
def parse_dtsx(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Parse control flow
    control_flow = parse_executables(root.findall('.//DTS:Executable'))
    
    return control_flow

# %%
file_path = 'data/DailyETLMain.dtsx'
control_flow, data_flow_info = parse_dtsx(file_path)

(control_flow, data_flow_info)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[29], line 2
#     control_flow, data_flow_info = parse_dtsx(file_path)
#
#   Cell In[28], line 33 in parse_dtsx
#     control_flow = parse_executables(root.findall('.//DTS:Executable'))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:411 in findall
#     return list(iterfind(elem, path, namespaces))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:384 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:185 in prepare_descendant
#     token = next()
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:87 in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File <string>
# SyntaxError: prefix 'DTS' not found in prefix map

# %%
file_path = 'data/ISP_01.dtsx' # good
control_flow, data_flow_info = parse_dtsx(file_path)

(control_flow, data_flow_info)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[30], line 2
#     control_flow, data_flow_info = parse_dtsx(file_path)
#
#   Cell In[28], line 33 in parse_dtsx
#     control_flow = parse_executables(root.findall('.//DTS:Executable'))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:411 in findall
#     return list(iterfind(elem, path, namespaces))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:384 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:185 in prepare_descendant
#     token = next()
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:87 in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File <string>
# SyntaxError: prefix 'DTS' not found in prefix map

# %%
file_path = 'data/ISP_02.dtsx' # good
control_flow, data_flow_info = parse_dtsx(file_path)

(control_flow, data_flow_info)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[31], line 2
#     control_flow, data_flow_info = parse_dtsx(file_path)
#
#   Cell In[28], line 33 in parse_dtsx
#     control_flow = parse_executables(root.findall('.//DTS:Executable'))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:411 in findall
#     return list(iterfind(elem, path, namespaces))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:384 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:185 in prepare_descendant
#     token = next()
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:87 in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File <string>
# SyntaxError: prefix 'DTS' not found in prefix map

# %%
file_path = 'data/ISP_04.dtsx' # good
control_flow, data_flow_info = parse_dtsx(file_path)

(control_flow, data_flow_info)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[32], line 2
#     control_flow, data_flow_info = parse_dtsx(file_path)
#
#   Cell In[28], line 33 in parse_dtsx
#     control_flow = parse_executables(root.findall('.//DTS:Executable'))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:411 in findall
#     return list(iterfind(elem, path, namespaces))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:384 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:185 in prepare_descendant
#     token = next()
#
#   File c:\Users\PietroGarroni\anaconda3\envs\rabo\lib\xml\etree\ElementPath.py:87 in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File <string>
# SyntaxError: prefix 'DTS' not found in prefix map

# %% [markdown]
# ## Convert to json

# %%
class Load():
    def __init__(self, path):
        self.path = path


    def remove_at_signs(self, obj):
        if isinstance(obj, dict):
            return {key.replace('@', ''): self.remove_at_signs(value) for key, value in obj.items()}
        elif isinstance(obj, list):
            return [self.remove_at_signs(item) for item in obj]
        else:
            return obj
        

    def remove_first_layer(self, json_dict):
        # Extract values from the first layer
        values = list(json_dict.values())
        return values

    def run(self):

        # Path to the XML file
        with open(self.path, 'rb') as f:
            self.xml = f.read()

   
        # open the xml file
        o = xmltodict.parse(self.xml)  # every time you reload the file in colab the key changes (file (1).xml becomes file (2).xml ...)

        json = self.remove_first_layer(self.remove_at_signs(o))[0]

        return json
    


files = [file for file in os.listdir('data/')]
#files = [file for file in os.listdir('data/Creating a Simple ETL Package/Completed Packages/')]

nodes_list = []
filter_list = []

for file in files[:2]:
    

    if file.endswith('.dtsx'):
        print(file)
        json = Load(f"data/{file}").run()
        #json = Load(f'data/Creating a Simple ETL Package/Completed Packages/{file}').run()
    #print(json)
# Out:
# DailyETLMain.dtsx

# %%
# print control flow nodes and data flow nodes tree


for control_node in json['DTS:Executables']['DTS:Executable']:

    print("control node name: ",control_node['DTS:ObjectName'])
    print("control node description: ",control_node['DTS:Description'])

    print()

    if control_node['DTS:Description'] == 'Sequence Container':
        for executable in control_node['DTS:Executables']['DTS:Executable']:
           # print("     ", executable)
            print("     executable name: ", executable['DTS:ObjectName'])
            print("     executable description: ", executable['DTS:Description'])

            #print()

            if executable['DTS:CreationName'] == 'Microsoft.Pipeline': # if the node is a pipeline, then get into data flow components (source and destination)

                for component in executable['DTS:ObjectData']['pipeline']['components']['component']:
                    print()
                    print("          component name: ", component['name'])
                    print("          component description: ", component['description'])
                    print("          component properties: ", component['properties'])

                    for property in component['properties']['property']:

                        # !!! remove the ifs, does not depend on source and destination!!!!!
                        if property['name'] == 'SqlCommand' and component['description'] == 'OLE DB Source': # extract sql command
                            print("          SQL command: ", property['#text'])
                        if property['name'] == 'OpenRowset' and component['description'] == 'OLE DB Destination':  # extract source or destination tables (change if)
                            print("          table name: ", property['#text'])
                        if property['name'] == 'ParameterMapping' and component['description'] == 'OLE DB Source': # list of variables of sql query
                            print("          parameters query: ", property['#text'])
                    print()

            elif executable['DTS:CreationName'] =='Microsoft.ExecuteSQLTask': # if the task is ExecuteSQL then print query and variables
                print("     SQL query: ", executable['DTS:ObjectData']['SQLTask:SqlTaskData']['SQLTask:SqlStatementSource'])
                try:
                    variables = executable['DTS:ObjectData']['SQLTask:SqlTaskData']['SQLTask:ParameterBinding']
                    if type(variables) == list:
                        print("     Variables: ", [i['SQLTask:DtsVariableName'] for i in executable['DTS:ObjectData']['SQLTask:SqlTaskData']['SQLTask:ParameterBinding']])
                    elif type(variables) == dict:
                        print("     Variables: ", executable['DTS:ObjectData']['SQLTask:SqlTaskData']['SQLTask:ParameterBinding']['SQLTask:DtsVariableName'])
                except: 
                    pass

                print()

            elif executable['DTS:CreationName'] =='Microsoft.ExpressionTask': 
                print("     SQL query: ", executable['DTS:ObjectData']['ExpressionTask']['Expression'])
                print()
# Out:
# control node name:  Calculate ETL Cutoff Time backup
# control node description:  Expression Task
#
# control node name:  Ensure Date Dimension includes current year
# control node description:  Execute SQL Task
#
# control node name:  Load City Dimension
# control node description:  Sequence Container
#
#      executable name:  Extract Updated City Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_City_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[City_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[City_Staging]
#
#
#           component name:  Integration_GetCityUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetCityUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI City ID] int,\n        City nvarchar(50),\n        [State Province] nvarchar(50),\n        Country nvarchar(50),\n        Continent nvarchar(30),\n        [Sales Territory] nvarchar(50),\n        Region nvarchar(30),\n        Subregion nvarchar(30),\n        [Location] geography,\n        [Latest Recorded Population] bigint,\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetCityUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [WWI City ID] int,
#         City nvarchar(50),
#         [State Province] nvarchar(50),
#         Country nvarchar(50),
#         Continent nvarchar(30),
#         [Sales Territory] nvarchar(50),
#         Region nvarchar(30),
#         Subregion nvarchar(30),
#         [Location] geography,
#         [Latest Recorded Population] bigint,
#         [Valid From] datetime2(7),
#         [Valid To] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#      executable name:  Get Last City ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged City Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedCityData;
#
#      executable name:  Set TableName to City
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "City"
#
#      executable name:  Truncate City_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.City_Staging;
#
# control node name:  Load Customer Dimension
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Customer Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_Customer_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Customer_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Customer_Staging]
#
#
#           component name:  Integration_GetCustomerUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetCustomerUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Customer ID] int,\n        Customer nvarchar(100),\n        [Bill To Customer] nvarchar(100),\n        Category nvarchar(50),\n        [Buying Group] nvarchar(50),\n        [Primary Contact] nvarchar(50),\n        [Postal Code] nvarchar(10),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetCustomerUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [WWI Customer ID] int,
#         Customer nvarchar(100),
#         [Bill To Customer] nvarchar(100),
#         Category nvarchar(50),
#         [Buying Group] nvarchar(50),
#         [Primary Contact] nvarchar(50),
#         [Postal Code] nvarchar(10),
#         [Valid From] datetime2(7),
#         [Valid To] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#      executable name:  Get Last Customer ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Customer Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedCustomerData;
#
#      executable name:  Set TableName to Customer
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Customer"
#
#      executable name:  Truncate Customer_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Customer_Staging;
#
# control node name:  Load Employee Dimension
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Employee Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_Employee_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Employee_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Employee_Staging]
#
#
#           component name:  Integration_GetEmployeeUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetEmployeeUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Employee ID] int,\n        Employee nvarchar(50),\n        [Preferred Name] nvarchar(50),\n        [Is Salesperson] bit,\n        Photo varbinary(max),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetEmployeeUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [WWI Employee ID] int,
#         Employee nvarchar(50),
#         [Preferred Name] nvarchar(50),
#         [Is Salesperson] bit,
#         Photo varbinary(max),
#         [Valid From] datetime2(7),
#         [Valid To] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#      executable name:  Get Last Employee ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Employee Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedEmployeeData;
#
#      executable name:  Set TableName to Employee
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Employee"
#
#      executable name:  Truncate Employee_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Employee_Staging;
#
# control node name:  Load Movement Fact
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Movement Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetMovementUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetMovementUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [Date Key] date,\n        [WWI Stock Item Transaction ID] int,\n        [WWI Invoice ID] int,\n        [WWI Purchase Order ID] int,\n        [Quantity] int,\n        [WWI Stock Item ID] int,\n        [WWI Customer ID] int,\n        [WWI Supplier ID] int,\n        [WWI Transaction Type ID] int,\n        [Last Modified When] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetMovementUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [Date Key] date,
#         [WWI Stock Item Transaction ID] int,
#         [WWI Invoice ID] int,
#         [WWI Purchase Order ID] int,
#         [Quantity] int,
#         [WWI Stock Item ID] int,
#         [WWI Customer ID] int,
#         [WWI Supplier ID] int,
#         [WWI Transaction Type ID] int,
#         [Last Modified When] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_Movement_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Movement_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Movement_Staging]
#
#      executable name:  Get Last Movement ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Movement Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedMovementData;
#
#      executable name:  Set TableName to Movement
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Movement"
#
#      executable name:  Truncate Movement_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Movement_Staging;
#
# control node name:  Load Order Fact
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Order Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetOrderUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetOrderUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [Order Date Key] date,\n        [Picked Date Key] date,\n        [WWI Order ID] int,\n        [WWI Backorder ID] int,\n        [Description] nvarchar(100),\n        [Package] nvarchar(50),\n        Quantity int,\n        [Unit Price] decimal(18,2),\n        [Tax Rate] decimal(18,3),\n        [Total Excluding Tax] decimal(18,2),\n        [Tax Amount] decimal(18,2),\n        [Total Including Tax] decimal(18,2),\n        [WWI City ID] int,\n        [WWI Customer ID] int,\n        [WWI Stock Item ID] int,\n        [WWI Salesperson ID] int,\n        [WWI Picker ID] int,\n        [Last Modified When] datetime2(7)\n\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetOrderUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [Order Date Key] date,
#         [Picked Date Key] date,
#         [WWI Order ID] int,
#         [WWI Backorder ID] int,
#         [Description] nvarchar(100),
#         [Package] nvarchar(50),
#         Quantity int,
#         [Unit Price] decimal(18,2),
#         [Tax Rate] decimal(18,3),
#         [Total Excluding Tax] decimal(18,2),
#         [Tax Amount] decimal(18,2),
#         [Total Including Tax] decimal(18,2),
#         [WWI City ID] int,
#         [WWI Customer ID] int,
#         [WWI Stock Item ID] int,
#         [WWI Salesperson ID] int,
#         [WWI Picker ID] int,
#         [Last Modified When] datetime2(7)
#
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_Order_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Order_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Order_Staging]
#
#      executable name:  Get Last Movement ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Order Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedOrderData;
#
#      executable name:  Set TableName to Order
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Order"
#
#      executable name:  Truncate Order_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Order_Staging;
#
# control node name:  Load Payment Method Dimension
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Payment Method Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetPaymentMethodUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetPaymentMethodUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Payment Method ID] int,\n        [Payment Method] nvarchar(50),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetPaymentMethodUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [WWI Payment Method ID] int,
#         [Payment Method] nvarchar(50),
#         [Valid From] datetime2(7),
#         [Valid To] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_PaymentMethod_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[PaymentMethod_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[PaymentMethod_Staging]
#
#      executable name:  Get Last Payment Method ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Payment Method Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedPaymentMethodData;
#
#      executable name:  Set TableName to Payment Method
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Payment Method"
#
#      executable name:  Truncate PaymentMethod_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.PaymentMethod_Staging;
#
# control node name:  Load Purchase Fact
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Purchase Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetPurchaseUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor', '#text': 'EXEC Integration.GetPurchaseUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [Date Key] date,\n        [WWI Purchase Order ID] int,\n        [Ordered Outers] int,\n        [Ordered Quantity] int,\n        [Received Outers] int,\n        [Package] nvarchar(50),\n        [Is Order Line Finalized] bit,\n        [WWI Supplier ID] int,\n        [WWI Stock Item ID] int,\n        [Last Modified When] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetPurchaseUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [Date Key] date,
#         [WWI Purchase Order ID] int,
#         [Ordered Outers] int,
#         [Ordered Quantity] int,
#         [Received Outers] int,
#         [Package] nvarchar(50),
#         [Is Order Line Finalized] bit,
#         [WWI Supplier ID] int,
#         [WWI Stock Item ID] int,
#         [Last Modified When] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_Purchase_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Purchase_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Purchase_Staging]
#
#      executable name:  Get Last Movement ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Purchase Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedPurchaseData;
#
#      executable name:  Set TableName to Purchase
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Purchase"
#
#      executable name:  Truncate Purchase_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Order_Staging;
#
# control node name:  Load Sale Fact
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Sale Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetSaleUpdates
#           component description:  OLE DB Source
# ...
#           table name:  [Integration].[Supplier_Staging]
#
#      executable name:  Get Last Supplier ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Supplier Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedSupplierData;
#
#      executable name:  Set TableName to Supplier
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Supplier"
#
#      executable name:  Truncate Supplier_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Supplier_Staging;
#
# control node name:  Load Transaction Fact
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Transaction Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetTransactionUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91', '#text': 'EXEC Integration.GetTransactionUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [Date Key] date,\n        [WWI Customer Transaction ID] int,\n        [WWI Supplier Transaction ID] int,\n        [WWI Invoice ID] int,\n        [WWI Purchase Order ID] int,\n        [Supplier Invoice Number] nvarchar(20),\n        [Total Excluding Tax] decimal(18,2),\n        [Tax Amount] decimal(18,2),\n        [Total Including Tax] decimal(18,2),\n        [Outstanding Balance] decimal(18,2),\n        [Is Finalized] bit,\n        [WWI Customer ID] int,\n        [WWI Bill To Customer ID] int,\n        [WWI Supplier ID] int,\n        [WWI Transaction Type ID] int,\n        [WWI Payment Method ID] int,\n        [Last Modified When] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetTransactionUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [Date Key] date,
#         [WWI Customer Transaction ID] int,
#         [WWI Supplier Transaction ID] int,
#         [WWI Invoice ID] int,
#         [WWI Purchase Order ID] int,
#         [Supplier Invoice Number] nvarchar(20),
#         [Total Excluding Tax] decimal(18,2),
#         [Tax Amount] decimal(18,2),
#         [Total Including Tax] decimal(18,2),
#         [Outstanding Balance] decimal(18,2),
#         [Is Finalized] bit,
#         [WWI Customer ID] int,
#         [WWI Bill To Customer ID] int,
#         [WWI Supplier ID] int,
#         [WWI Transaction Type ID] int,
#         [WWI Payment Method ID] int,
#         [Last Modified When] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_Transaction_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[Transaction_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[Transaction_Staging]
#
#      executable name:  Get Last Movement ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Transaction Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedTransactionData;
#
#      executable name:  Set TableName to Transaction
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Transaction"
#
#      executable name:  Truncate Transaction_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.Transaction_Staging;
#
# control node name:  Load Transaction Type Dimension
# control node description:  Sequence Container
#
#      executable name:  Extract Updated Transaction Type Data to Staging
#      executable description:  Data Flow Task
#
#           component name:  Integration_GetTransactionTypeUpdates
#           component description:  OLE DB Source
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91', '#text': 'EXEC Integration.GetTransactionTypeUpdates ?, ?\nWITH RESULT SETS\n(\n    (\n        [WWI Transaction Type ID] int,\n        [Transaction Type] nvarchar(50),\n        [Valid From] datetime2(7),\n        [Valid To] datetime2(7)\n    )\n);'}, {'dataType': 'System.String', 'description': 'The variable that contains the SQL command to be executed.', 'name': 'SqlCommandVariable'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '2'}, {'dataType': 'System.String', 'description': 'The mappings between the parameters in the SQL command and variables.', 'name': 'ParameterMapping', '#text': '"@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};'}]}
#           SQL command:  EXEC Integration.GetTransactionTypeUpdates ?, ?
# WITH RESULT SETS
# (
#     (
#         [WWI Transaction Type ID] int,
#         [Transaction Type] nvarchar(50),
#         [Valid From] datetime2(7),
#         [Valid To] datetime2(7)
#     )
# );
#           parameters query:  "@LastCutoff:Input",{60BD9010-4784-49A6-8FF2-340D7AB3B70D};"@NewCutoff:Input",{B96D08A3-EC4E-45C1-8E78-526920753C6B};
#
#
#           component name:  Integration_TransactionType_Staging
#           component description:  OLE DB Destination
#           component properties:  {'property': [{'dataType': 'System.Int32', 'description': 'The number of seconds before a command times out.  A value of 0 indicates an infinite time-out.', 'name': 'CommandTimeout', '#text': '0'}, {'dataType': 'System.String', 'description': 'Specifies the name of the database object used to open a rowset.', 'name': 'OpenRowset', '#text': '[Integration].[TransactionType_Staging]'}, {'dataType': 'System.String', 'description': 'Specifies the variable that contains the name of the database object used to open a rowset.', 'name': 'OpenRowsetVariable'}, {'dataType': 'System.String', 'description': 'The SQL command to be executed.', 'name': 'SqlCommand', 'UITypeEditor': 'Microsoft.DataTransformationServices.Controls.ModalMultilineStringEditor, Microsoft.DataTransformationServices.Controls, Version=16.0.0.0, Culture=neutral, PublicKeyToken=89845dcd8080cc91'}, {'dataType': 'System.Int32', 'description': 'Specifies the column code page to use when code page information is unavailable from the data source.', 'name': 'DefaultCodePage', '#text': '1252'}, {'dataType': 'System.Boolean', 'description': 'Forces the use of the DefaultCodePage property value when describing character data.', 'name': 'AlwaysUseDefaultCodePage', '#text': 'false'}, {'dataType': 'System.Int32', 'description': 'Specifies the mode used to access the database.', 'name': 'AccessMode', 'typeConverter': 'AccessMode', '#text': '3'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the values supplied for identity columns will be copied to the destination. If false, values for identity columns will be auto-generated at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepIdentity', '#text': 'false'}, {'dataType': 'System.Boolean', 'description': 'Indicates whether the columns containing null will have null inserted in the destination. If false, columns containing null will have their default values inserted at the destination. Applies only if fast load is turned on.', 'name': 'FastLoadKeepNulls', '#text': 'false'}, {'dataType': 'System.String', 'description': 'Specifies options to be used with fast load.  Applies only if fast load is turned on.', 'name': 'FastLoadOptions', '#text': 'CHECK_CONSTRAINTS'}, {'dataType': 'System.Int32', 'description': 'Specifies when commits are issued during data insertion.  A value of 0 specifies that one commit will be issued at the end of data insertion.  Applies only if fast load is turned on.', 'name': 'FastLoadMaxInsertCommitSize', '#text': '2147483647'}]}
#           table name:  [Integration].[TransactionType_Staging]
#
#      executable name:  Get Last Transaction Type ETL Cutoff Time
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLastETLCutoffTime ?;
#      Variables:  User::TableName
#
#      executable name:  Get Lineage Key
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.GetLineageKey ?, ?;
#      Variables:  ['User::TableName', 'User::TargetETLCutoffTime']
#
#      executable name:  Migrate Staged Transaction Type Data
#      executable description:  Execute SQL Task
#      SQL query:  EXEC Integration.MigrateStagedTransactionTypeData;
#
#      executable name:  Set TableName to Transaction Type
#      executable description:  Expression Task
#      SQL query:  @[User::TableName] = "Transaction Type"
#
#      executable name:  Truncate TransactionType_Staging
#      executable description:  Execute SQL Task
#      SQL query:  DELETE FROM Integration.TransactionType_Staging;
#
# control node name:  Trim Any Milliseconds
# control node description:  Expression Task

# %%
# order nodes in sequence containers

def sort_precedeneces(precedences_list, precedences_list_sorted):

    # for element in precedence list, recursively add all the node one by one in order
    for i in precedences_list:
        # if the last element of the sorted list is the same as the first element of the list of lists
        if precedences_list_sorted[-1] == i[0]:

            precedences_list_sorted.append(i[1]) # append to sorted list
            sort_precedeneces(precedences_list, precedences_list_sorted) # recursively recall the function

    return precedences_list_sorted


            
for control_node in json['DTS:Executables']['DTS:Executable']:
    #print(control_node)
    precedences_list = []

    # if node is sequence node
    if control_node['DTS:Description'] == 'Sequence Container':
        print("control node name: ", control_node['DTS:ObjectName'])

        # for precedences in precedence, create list of lists where each list contains the from and to nodes
        for constraint in control_node['DTS:PrecedenceConstraints']['DTS:PrecedenceConstraint']:
            ffrom = f"{constraint['DTS:From']}".split("\\")[-1]
            to = f"{constraint['DTS:To']}".split("\\")[-1]

            precedences_list.append([ffrom, to])

        list_1 = [i[1] for i in precedences_list] # list with second elements of all pairs

        precedences_list_sorted = []

        # for element in precedence list, 
        for i in precedences_list:
            # if the first node is never a second node then the node is the first one in the sequence container, therefore append both elements to list, as first and second, then keep adding until done
            if i[0] not in list_1:
                precedences_list_sorted.append(i[0])
                precedences_list_sorted.append(i[1])


        print(sort_precedeneces(precedences_list, precedences_list_sorted))
        print()
# Out:
# control node name:  Load City Dimension
# ['Set TableName to City', 'Get Lineage Key', 'Truncate City_Staging', 'Get Last City ETL Cutoff Time', 'Extract Updated City Data to Staging', 'Migrate Staged City Data']
#
# control node name:  Load Customer Dimension
# ['Set TableName to Customer', 'Get Lineage Key', 'Truncate Customer_Staging', 'Get Last Customer ETL Cutoff Time', 'Extract Updated Customer Data to Staging', 'Migrate Staged Customer Data']
#
# control node name:  Load Employee Dimension
# ['Set TableName to Employee', 'Get Lineage Key', 'Truncate Employee_Staging', 'Get Last Employee ETL Cutoff Time', 'Extract Updated Employee Data to Staging', 'Migrate Staged Employee Data']
#
# control node name:  Load Movement Fact
# ['Set TableName to Movement', 'Get Lineage Key', 'Truncate Movement_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract Updated Movement Data to Staging', 'Migrate Staged Movement Data']
#
# control node name:  Load Order Fact
# ['Set TableName to Order', 'Get Lineage Key', 'Truncate Order_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract Updated Order Data to Staging', 'Migrate Staged Order Data']
#
# control node name:  Load Payment Method Dimension
# ['Set TableName to Payment Method', 'Get Lineage Key', 'Truncate PaymentMethod_Staging', 'Get Last Payment Method ETL Cutoff Time', 'Extract Updated Payment Method Data to Staging', 'Migrate Staged Payment Method Data']
#
# control node name:  Load Purchase Fact
# ['Set TableName to Purchase', 'Get Lineage Key', 'Truncate Purchase_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract Updated Purchase Data to Staging', 'Migrate Staged Purchase Data']
#
# control node name:  Load Sale Fact
# ['Set TableName to Sale', 'Get Lineage Key', 'Truncate Sale_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract Updated Sale Data to Staging', 'Migrate Staged Sale Data']
#
# control node name:  Load Stock Holding Fact
# ['Set TableName to Stock Holding', 'Get Lineage Key', 'Truncate StockHolding_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract All Stock Holding Data to Staging', 'Migrate Staged Stock Holding Data']
#
# control node name:  Load Stock Item Dimension
# ['Set TableName to Stock Item', 'Get Lineage Key', 'Truncate StockItem_Staging', 'Get Last Stock Item ETL Cutoff Time', 'Extract Updated Stock Item Data to Staging', 'Migrate Staged Stock Item Data']
#
# control node name:  Load Supplier Dimension
# ['Set TableName to Supplier', 'Get Lineage Key', 'Truncate Supplier_Staging', 'Get Last Supplier ETL Cutoff Time', 'Extract Updated Supplier Data to Staging', 'Migrate Staged Supplier Data']
#
# control node name:  Load Transaction Fact
# ['Set TableName to Transaction', 'Get Lineage Key', 'Truncate Transaction_Staging', 'Get Last Movement ETL Cutoff Time', 'Extract Updated Transaction Data to Staging', 'Migrate Staged Transaction Data']
#
# control node name:  Load Transaction Type Dimension
# ['Set TableName to Transaction Type', 'Get Lineage Key', 'Truncate TransactionType_Staging', 'Get Last Transaction Type ETL Cutoff Time', 'Extract Updated Transaction Type Data to Staging', 'Migrate Staged Transaction Type Data']
